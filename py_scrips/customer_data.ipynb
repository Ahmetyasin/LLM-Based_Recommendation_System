# %% [markdown]
# # Parse Data

# %%
import pandas as pd
import gzip
import json
import pickle

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield json.loads(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

# %%
df_fashion = pd.read_pickle('df_fashion.pkl')
df_elect = pd.read_pickle('df_elect.pkl')
df_cloth = pd.read_pickle('df_cloth.pkl')
df_home = pd.read_pickle('df_home.pkl')

# %%
# Read the JSON file line by line and load the objects into a list of dictionaries
data = []
with open('Home_and_Kitchen_5.json', 'r') as f:
    for line in f:
        data.append(json.loads(line))

df_home = pd.DataFrame(data)

# %% [markdown]
# # Merging each data with their meta

# %%
count_fashion = df_fashion['reviewerID'].value_counts()
count_elect = df_elect['reviewerID'].value_counts()
count_cloth = df_cloth['reviewerID'].value_counts()
count_home = df_home['reviewerID'].value_counts()
# Combine the counts
combined_count = count_fashion.add(count_elect, fill_value=0).add(count_cloth, fill_value=0).add(count_home, fill_value=0)
# Filter the combined_count Series to see only the rows where the count is at least five
at_least_five = combined_count[combined_count >= 20]
#result to a DataFrame
at_least_five_df = at_least_five.reset_index().rename(columns={'index': 'Reviewer_id', 0: 'count'})
print(at_least_five_df)
# Out:
#                  Reviewer_id  reviewerID
# 0       A0039616ADOZ0KMWQRNX        21.0
# 1       A0053783WS05FZ73CBKH        25.0
# 2       A0103849GBVWICKXD4T6        23.0
# 3       A0131404LSWOFZO68ETE        24.0
# 4       A0139874ED7NYUB55TSR        20.0
# ...                      ...         ...
# 166697         AZZXCFBNEWIBQ       201.0
# 166698         AZZXJAE2DILET        20.0
# 166699         AZZY4W8E5AX2K        39.0
# 166700         AZZYJH0XNZ896        28.0
# 166701         AZZYW4YOE1B6E        65.0
#
# [166702 rows x 2 columns]

# %%
# Count occurrences of 'Reviewer_id' in each DataFrame
count_elect = df_elect['reviewerID'].value_counts()
count_cloth = df_cloth['reviewerID'].value_counts()
count_home = df_home['reviewerID'].value_counts()
# Filter the counts to find customers who appear more than 20 times in each DataFrame
two_times_elect = count_elect[count_elect >= 20].index
two_times_cloth = count_cloth[count_cloth >= 20].index
two_times_home = count_home[count_home >= 20].index
# Find the intersection of the 'Reviewer_id's that meet the criteria for all four DataFrames
common_reviewers = set(two_times_cloth).intersection(two_times_elect, two_times_home)
# Subset each original DataFrame to include only the rows with 'Reviewer_id's that meet the criteria
# subset_fashion = df_fashion[df_fashion['reviewerID'].isin(common_reviewers)]
subset_elect = df_elect[df_elect['reviewerID'].isin(common_reviewers)]
subset_cloth = df_cloth[df_cloth['reviewerID'].isin(common_reviewers)]
subset_home = df_home[df_home['reviewerID'].isin(common_reviewers)]
print("Subset Electronics:\n", subset_elect)
print("Subset Clothing:\n", subset_cloth)
print("Subset Home:\n", subset_home)
# Out:
# Subset Electronics:
#           overall vote  verified   reviewTime      reviewerID        asin  \
# 166          5.0  NaN      True  07 24, 2014  A320NYVVIZSZGY  0594481902
# 270          5.0  NaN      True   10 3, 2012  A21SESEJ8E52B7  0764207474
# 285          4.0  NaN     False  05 20, 2010  A2JCJJNY43QQIV  0789743035
# 319          3.0  NaN     False  05 20, 2010  A3U029B8Z5WGI2  0789743035
# 716          5.0  NaN      True  11 21, 2012  A3TAS1AG6FMBQW  0972683275
# ...          ...  ...       ...          ...             ...         ...
# 6737606      1.0  NaN     False  11 28, 2017  A30H2335OM7RD6  B01H747V80
# 6738162      4.0  NaN     False  07 23, 2016  A1JZFGZEZVWQPY  B01HBIETM8
# 6738813      5.0  NaN     False  09 30, 2018  A2I5QH4F5FDKK5  B01HETFPK4
# 6739480      5.0  NaN     False  12 21, 2016   AMLXY5B95T869  B01HIA63ZA
# 6739484      5.0    2     False   12 6, 2016  A3NM1MT3Q2FHXV  B01HIA63ZA
#
#                                   style   reviewerName  \
# 166                                 NaN  Colleen Marie
# 270      {'Format:': ' Kindle Edition'}        tweezle
# 285           {'Format:': ' Paperback'}      Katy Lake
# 319           {'Format:': ' Paperback'}      KttyKat16
# 716                                 NaN      Jeri Zerr
# ...                                 ...            ...
# 6737606           {'Color:': ' Silver'}          apoem
# 6738162                             NaN    Professor H
# 6738813     {'Color:': ' Aquatic blue'}         *rose*
# 6739480                             NaN           J.C.
# 6739484                             NaN      S.E. Poza
#
#                                                 reviewText  \
# 166      This AC adapter worked out just fine and as it...
# 270      When I looked at the cover art, I decided this...
# 285      this is a great idea. I know that virtually no...
# 319      My MacBook is a good step-by-step manual on th...
# 716      The VideoSecu line of articulating wall mounts...
# ...                                                    ...
# 6737606  I wanted to like these. I had them and tried t...
# 6738162  This review is for the Pomelo Best Bluetooth S...
# 6738813  This speaker is great.  We have another SoundL...
# 6739480  5 stars, "Fast, reliable SSD, even externally....
# 6739484  This is a 250 GB SSD drive that can be install...
#
#                                                    summary  unixReviewTime  \
# 166                     Gives my NOOKY the juice it needs!      1406160000
# 270                                    Highly recommended!      1349222400
# 285                     If you've never owned a Macbook...      1274313600
# 319      Nothing You Can't Find Online, but Easy to Fol...      1274313600
# 716      High quality construction, comes with plenty o...      1353456000
# ...                                                    ...             ...
# 6737606                         COuldn't get them to work.      1511827200
# 6738162  This review is for the Pomelo Best Bluetooth S...      1469232000
# 6738813                               Great little speaker      1538265600
# 6739480                 Fast, reliable SSD even externally      1482278400
# 6739484  noticeable speed improvements, easy installati...      1480982400
#
#                                                      image domain
# 166                                                    NaN  elect
# 270                                                    NaN  elect
# 285                                                    NaN  elect
# 319                                                    NaN  elect
# 716                                                    NaN  elect
# ...                                                    ...    ...
# 6737606                                                NaN  elect
# 6738162                                                NaN  elect
# 6738813                                                NaN  elect
# 6739480  [https://images-na.ssl-images-amazon.com/image...  elect
# 6739484                                                NaN  elect
#
# [52394 rows x 13 columns]
# Subset Clothing:
#            overall vote  verified   reviewTime      reviewerID        asin  \
# 779           3.0   14      True  09 17, 2010  A2YCEKVUN1W5F1  B00001TOXD
# 1001          5.0    5      True  09 25, 2006   AY49JOXTLDOG2  B00002243H
# 1002          5.0   25     False   08 6, 2003   A1RPTVW5VEOSI  B00002243H
# 1097          5.0   13      True   10 8, 2005  A30H2335OM7RD6  B000034DKZ
# 1888          4.0  NaN      True  10 16, 2014   ATJ22NADXNLD9  B0000696B9
# ...           ...  ...       ...          ...             ...         ...
# 11284368      5.0  NaN      True  06 16, 2017   AY3XPKRAMKKY7  B01HHMUSEG
# 11284369      5.0  NaN     False  04 20, 2017  A2Y739CRM15WDL  B01HHMUSEG
# 11284719      5.0    2     False  11 18, 2016  A2PSD2R9A1CXG7  B01HIATD2U
# 11284992      3.0  NaN      True  11 27, 2016  A2IH2H5NLHA6DD  B01HIPQ3B4
# 11285423      3.0  NaN     False  08 25, 2018   AGFW667QNHDOY  B01HJDVCJI
#
#                                                       style  \
# 779                                                     NaN
# 1001                                                    NaN
# 1002                                                    NaN
# 1097       {'Size:': ' One Size', 'Color:': ' Black/White'}
# 1888      {'Size:': ' XL(18-20)', 'Color:': ' Yellow/Red...
# ...                                                     ...
# 11284368                                                NaN
# 11284369                                                NaN
# 11284719                               {'Color:': ' Black'}
# 11284992                         {'Size Name:': ' X-Small'}
# 11285423  {'Size:': ' 12 M US', 'Color:': ' Trace Brown ...
#
#                                       reviewerName  \
# 779       K. Salinger, Holistic Nurse Practitioner
# 1001                 Jeff  &amp; Jeff&#039;s Wife
# 1002                            Michael J. Edelman
# 1097                                         apoem
# 1888                               Amazon Customer
# ...                                            ...
# 11284368                                C. G. King
# 11284369                                     Sires
# 11284719                               LT Beasimer
# 11284992                                K. benford
# 11285423                                 S. Lipson
#
#                                                  reviewText  \
# 779       This is one of the few witches brooms that was...
# 1001      No, I'm not a contractor. I work in a major tr...
# 1002      I've been carrying my Bucket Boss briefcase on...
# 1097      What a wonderful toy. It is easy to manipulate...
# 1888      This costume looks like the pic. It can be adj...
# ...                                                     ...
# 11284368  Soft and smooth fabric and is comfortable to w...
# 11284369  Very much better than what I've bought from di...
# 11284719  I travel several times a year and try to trave...
# 11284992  They seem to run a little large.  I have a siz...
# 11285423  My son did not like these. They fit about a fu...
#
#                                                     summary  unixReviewTime  \
# 779       kid size witch broom, poor construction - will...      1284681600
# 1001                   Great for Medical Professionals too!      1159142400
# 1002                              Not just for contractors!      1060128000
# 1097                 super easy, well made, enjoyable magic      1128729600
# 1888                   Looks nice but colors are a bit dull      1413417600
# ...                                                     ...             ...
# 11284368                                           Good buy      1497571200
# 11284369                                    Comfortable Fit      1492646400
# 11284719  On The Go With Delsey: A Delsey Luggage Comete...      1479427200
# 11284992                                              Nice!      1480204800
# 11285423                           Did not work out for us.      1535155200
#
#          image   domain
# 779        NaN  clothes
# 1001       NaN  clothes
# 1002       NaN  clothes
# 1097       NaN  clothes
# 1888       NaN  clothes
# ...        ...      ...
# 11284368   NaN  clothes
# 11284369   NaN  clothes
# 11284719   NaN  clothes
# 11284992   NaN  clothes
# 11285423   NaN  clothes
#
# [36998 rows x 13 columns]
# Subset Home:
#              reviewerID        asin                 reviewerName   helpful  \
# 3       A2MHCTX43MIMDZ  0615391206       M. Johnson "Tea Lover"  [14, 18]
# 7       A1ZH5ULI4SBO48  0615391206                 S. G. "s.g."  [32, 39]
# 33       ATJ22NADXNLD9  0912696591      Cardona "Cosmopolitana"    [1, 1]
# 105     A2VWE5SGNDS8HW  0912696591              tachi1 "tachi1"  [15, 15]
# 123     A34UVV757IKPVB  1567120709                  justsomeguy    [0, 0]
# ...                ...         ...                          ...       ...
# 551591  A2BYV7S1QP2YIG  B00KY4Z1I8  Dr. Oceanfront "Oceanfront"    [2, 2]
# 551593  A1UQBFCERIP7VJ  B00KY4Z1I8               Margaret Picky    [0, 0]
# 551649   ABDR6IJ93HFIO  B00LAI4UYS              Daisy "Daisy S"    [0, 0]
# 551650   AZMY6E8B52L2T  B00LAI4UYS                    JP "J.P."    [0, 0]
# 551651  A2NYK9KWFMJV4Y  B00LAI4UYS  Mike Tarrani "Jazz Drummer"    [0, 0]
#
#                                                reviewText  overall  \
# 3       This book is a must have if you get a Zoku (wh...      5.0
# 7       I bought this when I bought the pop maker. I t...      2.0
# 33      I love this booklet! It is light and slim so i...      5.0
# 105     On the whole, I like this book very much. I ha...      4.0
# 123     I used to date this girl who loved Scrabble.  ...      5.0
# ...                                                   ...      ...
# 551591  I was offered this bag for review, and I agree...      5.0
# 551593  Sometimes it is the simple things in life that...      5.0
# 551649  This set is just what I have been looking for ...      5.0
# 551650  I was very excited to get to try theZhuhai Pre...      5.0
# 551651  I received this set as a review sample and fin...      5.0
#
#                                                   summary  unixReviewTime  \
# 3                                         Creative Combos      1312416000
# 7       Okay but you can figure it out yourself withou...      1323302400
# 33                                  Great reference book!      1304899200
# 105     Companion booklet for Level 3 Fondant & Gum Paste      1331596800
# 123                          I use it for Scrabble games.      1325808000
# ...                                                   ...             ...
# 551591                               Works really well...      1405123200
# 551593                            A superior nut milk bag      1405987200
# 551649  Very attractive ceramic knife set with stylish...      1404777600
# 551650                               Great For Slicing...      1404950400
# 551651                       Right tool for the right job      1404777600
#
#          reviewTime domain
# 3        08 4, 2011   home
# 7        12 8, 2011   home
# 33       05 9, 2011   home
# 105     03 13, 2012   home
# 123      01 6, 2012   home
# ...             ...    ...
# 551591  07 12, 2014   home
# 551593  07 22, 2014   home
# 551649   07 8, 2014   home
# 551650  07 10, 2014   home
# 551651   07 8, 2014   home
#
# [27881 rows x 10 columns]

# %%
subset_elect['reviewerID'].nunique()
# Out:
# 670

# %%
subset_elect.to_pickle("subset_elect.pkl")

# %%
subset_cloth.to_pickle("subset_cloth.pkl")

# %%
subset_home.to_pickle("subset_home.pkl")

# %%
#Read from pickled subset dfs
subset_elect = pd.read_pickle('subset_elect.pkl')
subset_cloth = pd.read_pickle('subset_cloth.pkl')
subset_home = pd.read_pickle('subset_home.pkl')

# %%
df_meta_fashion = getDF('meta_AMAZON_FASHION.json.gz')
df_meta_fashion.to_pickle("df_meta_fashion.pkl")

# %%
df_meta_elect = getDF('meta_Electronics.json.gz')
df_meta_elect.to_pickle("df_meta_elect.pkl")

# %%
df_meta_cloth = getDF('meta_Clothing_Shoes_and_Jewelry.json.gz')
df_meta_cloth.to_pickle("df_meta_cloth.pkl")

# %%
df_meta_home = getDF('meta_Home_and_Kitchen.json.gz')
df_meta_home.to_pickle("df_meta_home.pkl")

# %%
#read from pickled
df_meta_elect = pd.read_pickle('df_meta_elect.pkl')

# %%
df_meta_cloth = pd.read_pickle('df_meta_cloth.pkl')

# %%
df_meta_home = pd.read_pickle('df_meta_home.pkl')

# %% [markdown]
# # Combine each customer with meta data

# %%
merged_elect = pd.merge(subset_elect, df_meta_elect, on='asin')
merged_elect = merged_elect.drop(['vote','verified', 'image', 'tech1', 'fit'
                                 , 'tech2', 'similar_item', 'imageURL', 'imageURLHighRes', 'main_cat'], axis=1)

# %%
merged_cloth = pd.merge(subset_cloth, df_meta_cloth, on='asin')
merged_cloth = merged_cloth.drop(['vote','verified', 'image', 'tech1', 'fit'
                                 , 'tech2', 'similar_item', 'imageURL', 'imageURLHighRes', 'main_cat'], axis=1)

# %%
merged_home = pd.merge(subset_home, df_meta_home, on='asin')
merged_home = merged_home.drop(['helpful', 'tech1', 'fit', 'similar_item', 
                                'imageURL', 'imageURLHighRes', 'tech2', 'main_cat'], axis=1)
# Create a new column 'col3' with the content of 'col1'
merged_home['style'] = merged_home['feature']

# %%
sorted_elect_columns = sorted(merged_elect.columns)
sorted_cloth_columns = sorted(merged_cloth.columns)
sorted_home_columns = sorted(merged_home.columns)

# %%
# Check if the sorted columns in all dataframes are equal
if (sorted_elect_columns == sorted_cloth_columns == sorted_home_columns):
    print("All dataframes have the same columns.")
else:
    print("The dataframes have different columns.")
# Out:
# All dataframes have the same columns.

# %% [markdown]
# # Final Dataframe

# %%
# Reorder the columns in each dataframe based on the merged_fashion dataframe
merged_cloth = merged_cloth[sorted_elect_columns]
merged_home = merged_home[sorted_elect_columns]
# Concatenate the dataframes
final_df = pd.concat([merged_elect, merged_cloth, merged_home], ignore_index=True)

# %%
final_df['reviewerID'].value_counts()
# Out:
# A3OXHLG6DIBRW8    726
# AVU1ILDDYW301     691
# ADLVFFE4VBT8      654
# A23GFTVIETX7DS    596
# A22CW0ZHY3NJH8    596
#                  ...
# A1TRENCBXLC8AS     58
# A3HC4071HNLGLZ     57
# A3UWRQZV34509I     57
# A1W78VPTNJJOF0     56
# A8UM78SMPSHC0      50
# Name: reviewerID, Length: 670, dtype: int64

# %%
final_df['reviewerID'].nunique()
# Out:
# 670

# %%
final_df.to_pickle("final_df.pkl")

# %%
import pandas as pd
final_df = pd.read_pickle('final_df.pkl')

# %%
final_df.head()
# Out:
#    overall   reviewTime      reviewerID        asin  \
# 0      5.0  07 24, 2014  A320NYVVIZSZGY  0594481902
# 1      5.0   10 3, 2012  A21SESEJ8E52B7  0764207474
# 2      4.0  05 20, 2010  A2JCJJNY43QQIV  0789743035
# 3      3.0  05 20, 2010  A3U029B8Z5WGI2  0789743035
# 4      5.0  11 21, 2012  A3TAS1AG6FMBQW  0972683275
#
#                             style   reviewerName  \
# 0                             NaN  Colleen Marie
# 1  {'Format:': ' Kindle Edition'}        tweezle
# 2       {'Format:': ' Paperback'}      Katy Lake
# 3       {'Format:': ' Paperback'}      KttyKat16
# 4                             NaN      Jeri Zerr
#
#                                           reviewText  \
# 0  This AC adapter worked out just fine and as it...
# 1  When I looked at the cover art, I decided this...
# 2  this is a great idea. I know that virtually no...
# 3  My MacBook is a good step-by-step manual on th...
# 4  The VideoSecu line of articulating wall mounts...
#
#                                              summary  unixReviewTime domain  \
# 0                 Gives my NOOKY the juice it needs!      1406160000  elect
# 1                                Highly recommended!      1349222400  elect
# 2                 If you've never owned a Macbook...      1274313600  elect
# 3  Nothing You Can't Find Online, but Easy to Fol...      1274313600  elect
# 4  High quality construction, comes with plenty o...      1353456000  elect
#
#    ...                                        description  \
# 0  ...  [#############################################...
# 1  ...  [Two Desperate People--<BR>&#9;&#9;One With Al...
# 2  ...                                   [<b> </b>, , , ]
# 3  ...                                   [<b> </b>, , , ]
# 4  ...  [The videosecu TV mount is a mounting solution...
#
#                                                title  \
# 0  Barnes &amp; Noble OV/HB Universal Power Kit f...
# 1                                Not a Sparrow Falls
# 2                                         My MacBook
# 3                                         My MacBook
# 4  VideoSecu 24" Long Arm TV Wall Mount Low Profi...
#
#                                             also_buy  \
# 0                                                 []
# 1  [0764227289, 0764206680, 0764201670, 071808473...
# 2                                                 []
# 3                                                 []
# 4  [B000WYVBR0, B003O1UYHG, B002YV4WJS, B071HW7GS...
#
#                                brand  \
# 0                 Barnes &amp; Noble
# 1  Visit Amazon's Linda Nichols Page
# 2       Visit Amazon's John Ray Page
# 3       Visit Amazon's John Ray Page
# 4                          VideoSecu
#
#                                              feature  \
# 0  [Genuine Nook Charger + Genuine USB Charger Ca...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [Fits most 22" to 47" HDTV and some up to 55" ...
#
#                                                 rank  \
# 0  [>#55 in Electronics &gt; eBook Readers &amp; ...
# 1                               1,693,481 in Books (
# 2                               4,226,393 in Books (
# 3                               4,226,393 in Books (
# 4  [>#176 in Electronics &gt; Accessories &amp; S...
#
#                                            also_view               date  \
# 0  [059449771X, B00QZXQNNO, B014A9T98K, B00QZXQP5...   November 3, 2012
# 1               [0764201670, 0764227289, 0764206680]
# 2               [B001GN5OLK, B004FFVLYU, B07B7VFTN9]
# 3               [B001GN5OLK, B004FFVLYU, B07B7VFTN9]
# 4                                                 []  February 25, 2007
#
#     price details
# 0             NaN
# 1  $28.58     NaN
# 2             NaN
# 3             NaN
# 4  $34.99     NaN
#
# [5 rows x 21 columns]

# %%
final_df['domain'].value_counts()
# Out:
# elect      55207
# clothes    37341
# home       18471
# Name: domain, dtype: int64

# %%
#Inspect duplicate rows
duplicate_rows = final_df[final_df.duplicated(subset='reviewText', keep=False)]
# Display duplicate rows
duplicate_rows.shape
# Out:
# (20765, 21)

# %%
#get rid of duplicate rows from final_df
final_df = final_df.drop_duplicates(subset='reviewText', keep='first')
# Reset the index and drop the old index column
final_df.reset_index(drop=True, inplace=True)

# %%
final_df
# Out:
#        overall   reviewTime      reviewerID        asin  \
# 0          5.0  07 24, 2014  A320NYVVIZSZGY  0594481902
# 1          5.0   10 3, 2012  A21SESEJ8E52B7  0764207474
# 2          4.0  05 20, 2010  A2JCJJNY43QQIV  0789743035
# 3          3.0  05 20, 2010  A3U029B8Z5WGI2  0789743035
# 4          5.0  11 21, 2012  A3TAS1AG6FMBQW  0972683275
# ...        ...          ...             ...         ...
# 99821      5.0  07 17, 2014  A10Y058K7B96C6  B00KSRV3UQ
# 99822      5.0   07 7, 2014   A79372WBA9IJM  B00KSRV3UQ
# 99823      4.0  06 24, 2014  A3M6TSEV71537G  B00KSRV3UQ
# 99824      5.0   07 2, 2014  A1FDSZISWIXH1A  B00KSRV3UQ
# 99825      5.0  07 10, 2014  A3VZH0PWLQ9BB1  B00KSRV3UQ
#
#                                                    style  \
# 0                                                    NaN
# 1                         {'Format:': ' Kindle Edition'}
# 2                              {'Format:': ' Paperback'}
# 3                              {'Format:': ' Paperback'}
# 4                                                    NaN
# ...                                                  ...
# 99821  [Fully Stainless Steel, Holds 1000ml, or 34oz,...
# 99822  [Fully Stainless Steel, Holds 1000ml, or 34oz,...
# 99823  [Fully Stainless Steel, Holds 1000ml, or 34oz,...
# 99824  [Fully Stainless Steel, Holds 1000ml, or 34oz,...
# 99825  [Fully Stainless Steel, Holds 1000ml, or 34oz,...
#
#                        reviewerName  \
# 0                     Colleen Marie
# 1                           tweezle
# 2                         Katy Lake
# 3                         KttyKat16
# 4                         Jeri Zerr
# ...                             ...
# 99821                   midnight821
# 99822   Miss Kitty "Timid Observer"
# 99823                      Sibelius
# 99824  Terry "tcinsatx@yahoodotcom"
# 99825                        Tom B.
#
#                                               reviewText  \
# 0      This AC adapter worked out just fine and as it...
# 1      When I looked at the cover art, I decided this...
# 2      this is a great idea. I know that virtually no...
# 3      My MacBook is a good step-by-step manual on th...
# 4      The VideoSecu line of articulating wall mounts...
# ...                                                  ...
# 99821  In a world of bigger is better coffee pots, te...
# 99822  I love my coffee, but admittedly I&#8217;m not...
# 99823  This 34 ounce brushed, stainless steel French ...
# 99824  I'm a coffee achiever and have used a french p...
# 99825  This is a great press. Attractive, does the jo...
#
#                                                  summary  unixReviewTime  \
# 0                     Gives my NOOKY the juice it needs!      1406160000
# 1                                    Highly recommended!      1349222400
# 2                     If you've never owned a Macbook...      1274313600
# 3      Nothing You Can't Find Online, but Easy to Fol...      1274313600
# 4      High quality construction, comes with plenty o...      1353456000
# ...                                                  ...             ...
# 99821                      Durable, Compact, Nice Design      1405555200
# 99822  High scores on functionality and design.  I lo...      1404691200
# 99823           Excellent insulation, stylish on display      1403568000
# 99824  Makes a delicious cup of coffee and looks gorg...      1404259200
# 99825                  Great sturdy easy to clean press.      1404950400
#
#       domain  ...                                        description  \
# 0      elect  ...  [#############################################...
# 1      elect  ...  [Two Desperate People--<BR>&#9;&#9;One With Al...
# 2      elect  ...                                   [<b> </b>, , , ]
# 3      elect  ...                                   [<b> </b>, , , ]
# 4      elect  ...  [The videosecu TV mount is a mounting solution...
# ...      ...  ...                                                ...
# 99821   home  ...  [Enjoy fresh coffee every day with this elegan...
# 99822   home  ...  [Enjoy fresh coffee every day with this elegan...
# 99823   home  ...  [Enjoy fresh coffee every day with this elegan...
# 99824   home  ...  [Enjoy fresh coffee every day with this elegan...
# 99825   home  ...  [Enjoy fresh coffee every day with this elegan...
#
#                                                    title  \
# 0      Barnes &amp; Noble OV/HB Universal Power Kit f...
# 1                                    Not a Sparrow Falls
# 2                                             My MacBook
# 3                                             My MacBook
# 4      VideoSecu 24" Long Arm TV Wall Mount Low Profi...
# ...                                                  ...
# 99821  Francois et Mimi Stainless Steel Double Wall F...
# 99822  Francois et Mimi Stainless Steel Double Wall F...
# 99823  Francois et Mimi Stainless Steel Double Wall F...
# 99824  Francois et Mimi Stainless Steel Double Wall F...
# 99825  Francois et Mimi Stainless Steel Double Wall F...
#
#                                                 also_buy  \
# 0                                                     []
# 1      [0764227289, 0764206680, 0764201670, 071808473...
# 2                                                     []
# 3                                                     []
# 4      [B000WYVBR0, B003O1UYHG, B002YV4WJS, B071HW7GS...
# ...                                                  ...
# 99821                                                 []
# 99822                                                 []
# 99823                                                 []
# 99824                                                 []
# 99825                                                 []
#
#                                    brand  \
# 0                     Barnes &amp; Noble
# 1      Visit Amazon's Linda Nichols Page
# 2           Visit Amazon's John Ray Page
# 3           Visit Amazon's John Ray Page
# 4                              VideoSecu
# ...                                  ...
# 99821                   Francois et Mimi
# 99822                   Francois et Mimi
# 99823                   Francois et Mimi
# 99824                   Francois et Mimi
# 99825                   Francois et Mimi
#
#                                                  feature  \
# 0      [Genuine Nook Charger + Genuine USB Charger Ca...
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4      [Fits most 22" to 47" HDTV and some up to 55" ...
# ...                                                  ...
# 99821  [Fully Stainless Steel, Holds 1000ml, or 34oz,...
# 99822  [Fully Stainless Steel, Holds 1000ml, or 34oz,...
# 99823  [Fully Stainless Steel, Holds 1000ml, or 34oz,...
# 99824  [Fully Stainless Steel, Holds 1000ml, or 34oz,...
# 99825  [Fully Stainless Steel, Holds 1000ml, or 34oz,...
#
#                                                     rank  \
# 0      [>#55 in Electronics &gt; eBook Readers &amp; ...
# 1                                   1,693,481 in Books (
# 2                                   4,226,393 in Books (
# 3                                   4,226,393 in Books (
# 4      [>#176 in Electronics &gt; Accessories &amp; S...
# ...                                                  ...
# 99821  [>#113,830 in Kitchen & Dining (See Top 100 in...
# 99822  [>#113,830 in Kitchen & Dining (See Top 100 in...
# 99823  [>#113,830 in Kitchen & Dining (See Top 100 in...
# 99824  [>#113,830 in Kitchen & Dining (See Top 100 in...
# 99825  [>#113,830 in Kitchen & Dining (See Top 100 in...
#
#                                                also_view               date  \
# 0      [059449771X, B00QZXQNNO, B014A9T98K, B00QZXQP5...   November 3, 2012
# 1                   [0764201670, 0764227289, 0764206680]
# 2                   [B001GN5OLK, B004FFVLYU, B07B7VFTN9]
# 3                   [B001GN5OLK, B004FFVLYU, B07B7VFTN9]
# 4                                                     []  February 25, 2007
# ...                                                  ...                ...
# 99821  [B00MMQOZ1U, B076D3L55Y, B00009ADDS, B00009ADD...       June 6, 2014
# 99822  [B00MMQOZ1U, B076D3L55Y, B00009ADDS, B00009ADD...       June 6, 2014
# 99823  [B00MMQOZ1U, B076D3L55Y, B00009ADDS, B00009ADD...       June 6, 2014
# 99824  [B00MMQOZ1U, B076D3L55Y, B00009ADDS, B00009ADD...       June 6, 2014
# 99825  [B00MMQOZ1U, B076D3L55Y, B00009ADDS, B00009ADD...       June 6, 2014
#
#         price details
# 0                 NaN
# 1      $28.58     NaN
# 2                 NaN
# 3                 NaN
# 4      $34.99     NaN
# ...       ...     ...
# 99821              {}
# 99822              {}
# 99823              {}
# 99824              {}
# 99825              {}
#
# [99826 rows x 21 columns]

# %%
import pandas as pd
import numpy as np

def sample_five_rows(reviewer_id, df, domains):
    sampled_rows = []
    for domain in domains:
        domain_df = df[(df['reviewerID'] == reviewer_id) & (df['domain'] == domain)].sample(n=5, random_state=3)
        sampled_rows.append(domain_df)
    return pd.concat(sampled_rows)

# Filter: to only include reviewerIDs that appear at least 5 times in each domain
reviewer_counts = final_df.groupby(['reviewerID', 'domain']).size().unstack(fill_value=0)
valid_reviewer_ids = reviewer_counts[(reviewer_counts['elect'] >= 5) & (reviewer_counts['clothes'] >= 5) & (reviewer_counts['home'] >= 5)].index

# Randomly select 50 unique reviewerIDs
selected_reviewer_ids = np.random.choice(valid_reviewer_ids, size=5, replace=False)

domains = ['elect', 'clothes', 'home']
sampled_dfs = []

for reviewer_id in selected_reviewer_ids:
    sampled_df = sample_five_rows(reviewer_id, final_df, domains)
    sampled_dfs.append(sampled_df)

subset_df = pd.concat(sampled_dfs)
# Reset the index and drop the old index column
subset_df.reset_index(drop=True, inplace=True)

# %%
subset_df.shape
# Out:
# (75, 21)

# %%
subset_df['reviewerID'].value_counts()
# Out:
# A2KETRDA2QWM8M    15
# A3UKWQS8SRW6IO    15
# A1M92239OM8KPO    15
# A1S27P7KJO9I96    15
# A28Q0JA9H8WZOD    15
# Name: reviewerID, dtype: int64

# %%
subset_df['reviewerID'].nunique()
# Out:
# 5

# %% [markdown]
# # final_df cleaning

# %%
#copy final_df and exclude some unnecessary columns
cleaned_data = final_df[['reviewerID','reviewerName' ,'unixReviewTime' ,'asin', 'style', 'reviewText', 'overall', 
                       'domain', 'category', 'title', 'brand','date']].copy()

# %%
# Remove HTML tags and convert the 'date' column to datetime
cleaned_data['date'] = cleaned_data['date'].str.replace('<[^<]+?>', '')
cleaned_data['date'] = pd.to_datetime(cleaned_data['date'], format='%B %d, %Y', errors='coerce')
# Out:
# /var/folders/rq/1_3v65yd0yn38jrwqf85v40w0000gn/T/ipykernel_96134/1369819350.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   cleaned_data['date'] = cleaned_data['date'].str.replace('<[^<]+?>', '')

# %%
cleaned_data['date'] # rows are like June 6, 2014
#give nthe number of rows with empty date
cleaned_data['date'].isnull().sum() # 3787
#drop rows with empty date or empty string date or date with only white spaces
cleaned_data = cleaned_data[cleaned_data['date'].notna()]
cleaned_data = cleaned_data[cleaned_data['date'] != '']
cleaned_data = cleaned_data[cleaned_data['date'] != ' ']
#reset index
cleaned_data.reset_index(drop=True, inplace=True)
cleaned_data['date'].isnull().sum() # 0
# convert date to datetime
cleaned_data['date'] = pd.to_datetime(cleaned_data['date'], format='%B %d, %Y')

# %%
cleaned_data['date']
# Out:
# 0       2012-11-03
# 1       2007-02-25
# 2       2011-06-03
# 3       2011-06-03
# 4       2009-11-25
#            ...
# 52714   2014-06-06
# 52715   2014-06-06
# 52716   2014-06-06
# 52717   2014-06-06
# 52718   2014-06-06
# Name: date, Length: 52719, dtype: datetime64[ns]

# %%
import pandas as pd
import ast
def clean_style(style):
    # Handle string representation of dictionary or list
    if isinstance(style, str):
        try:
            style = ast.literal_eval(style)
        except (ValueError, SyntaxError):
            return style  # return the original string if it cannot be parsed
    # If it's a dictionary
    if isinstance(style, dict):
        useful_keys = ['Capacity:', 'Size:', 'Color:', 'Style:', 'style:']  # added 'Style:' and 'style:'
        return ', '.join([f'{k} {v}' for k, v in style.items() if k in useful_keys])
    # If it's a list
    elif isinstance(style, list):
        return ', '.join(style)  # you can add more processing here if you want
    # If it's neither a dictionary nor a list, convert it to a string
    else:
        return str(style)
# Apply the function to the 'style' column
cleaned_data['style'] = cleaned_data['style'].apply(clean_style)
# Drop rows where 'style' is an empty string
cleaned_data = cleaned_data[cleaned_data['style'].str.strip() != '']
# Drop rows where string 'nan' is written in the 'style' column
cleaned_data = cleaned_data[cleaned_data['style'].str.strip() != 'nan']

#for category column
def extract_last_element(list):
    return list[-1]

cleaned_data['category'] = cleaned_data['category'].apply(extract_last_element)

# %%
import pandas as pd
import re
def remove_text_inside_parentheses(df, column):
    df[column] = df[column].str.replace(r"\(.*?\)", "", regex=True)
    df[column] = df[column].str.replace(r"\[.*?\]", "", regex=True)
    return df
# Usage
cleaned_data = remove_text_inside_parentheses(cleaned_data, 'title')
#replace all commas with symbol - for title column
cleaned_data['title'] = cleaned_data['title'].str.replace(',', ' -')
#truncate title column to include only first 100 characters
cleaned_data['title'] = cleaned_data['title'].str[:48]
#drop rows where reviewText is more than the median length
cleaned_data = cleaned_data[cleaned_data['reviewText'].str.len() <= cleaned_data['reviewText'].str.len().median()]

# %%
# the median length in the reviewText column
cleaned_data['reviewText'].str.len().median()
# Out:
# 423.0

# %%
# see the entire cell for title column
pd.set_option('display.max_colwidth', -1)
cleaned_data['title'][900:950]
# Out:
# /var/folders/rq/1_3v65yd0yn38jrwqf85v40w0000gn/T/ipykernel_96134/2449507623.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
# /var/folders/rq/1_3v65yd0yn38jrwqf85v40w0000gn/T/ipykernel_96134/2449507623.py:3: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   cleaned_data['title'][900:950]
# 3776    StarTech.com 12in Power Cord Extension - NEMA 5-
# 3777    StarTech.com 12in Power Cord Extension - NEMA 5-
# 3778    StarTech.com 12in Power Cord Extension - NEMA 5-
# 3779    StarTech.com 12in Power Cord Extension - NEMA 5-
# 3780    Verbatim DVD+R DL 8.5GB 8X Surface - 5pk Jewel C
# 3781    Verbatim DVD+R DL 8.5GB 8X Surface - 5pk Jewel C
# 3782    Verbatim DVD+R DL 8.5GB 8X Surface - 5pk Jewel C
# 3783    Verbatim DVD+R DL 8.5GB 8X Surface - 5pk Jewel C
# 3784    Verbatim DVD+R DL 8.5GB 8X Surface - 5pk Jewel C
# 3787    PCT 1-PORT BI-DIRECTIONAL CABLE TV HDTV AMPLIFIE
# 3788    PCT 1-PORT BI-DIRECTIONAL CABLE TV HDTV AMPLIFIE
# 3789    PCT 1-PORT BI-DIRECTIONAL CABLE TV HDTV AMPLIFIE
# 3794    Lowepro Rezo 15
# 3826    Monster MP OTG400 BK Outlets To Go Power Strip -
# 3827    Monster MP OTG400 BK Outlets To Go Power Strip -
# 3828    Monster MP OTG400 BK Outlets To Go Power Strip -
# 3829    Monster MP OTG400 BK Outlets To Go Power Strip -
# 3830    Monster MP OTG400 BK Outlets To Go Power Strip -
# 3831    Monster MP OTG400 BK Outlets To Go Power Strip -
# 3835    Monster MP OTG400 BK Outlets To Go Power Strip -
# 3837    Monster MP OTG400 BK Outlets To Go Power Strip -
# 3838    Monster MP OTG400 BK Outlets To Go Power Strip -
# 3844    CyberPower  CP1500AVRLCD Intelligent LCD UPS Sys
# 3846    CyberPower  CP1500AVRLCD Intelligent LCD UPS Sys
# 3847    CyberPower  CP1500AVRLCD Intelligent LCD UPS Sys
# 3849    CyberPower  CP1500AVRLCD Intelligent LCD UPS Sys
# 3851    CyberPower  CP1500AVRLCD Intelligent LCD UPS Sys
# 3852    CyberPower  CP1500AVRLCD Intelligent LCD UPS Sys
# 3857    Tripp Lite 10 Outlet Home &amp; Office Power Str
# 3863    RCA RCR311BR Three-Device Universal Remote
# 3931    TP-Link 5 Port Fast Ethernet Switch | Desktop Et
# 3932    TP-Link 5 Port Fast Ethernet Switch | Desktop Et
# 3933    TP-Link 5 Port Fast Ethernet Switch | Desktop Et
# 3934    TP-Link 5 Port Fast Ethernet Switch | Desktop Et
# 3936    TP-Link 5 Port Fast Ethernet Switch | Desktop Et
# 3938    TP-Link 5 Port Fast Ethernet Switch | Desktop Et
# 3939    TP-Link 5 Port Fast Ethernet Switch | Desktop Et
# 3940    TP-Link 5 Port Fast Ethernet Switch | Desktop Et
# 3942    TP-Link 5 Port Fast Ethernet Switch | Desktop Et
# 3943    Battery Organizer Storage Case by Range Kleen Ho
# 3945    Battery Organizer Storage Case by Range Kleen Ho
# 3946    Battery Organizer Storage Case by Range Kleen Ho
# 3947    Battery Organizer Storage Case by Range Kleen Ho
# 3948    Battery Organizer Storage Case by Range Kleen Ho
# 3951    Battery Organizer Storage Case by Range Kleen Ho
# 3959    Panasonic PS-SLX1K Semi-Soft Leather Camera Case
# 3960    Panasonic PS-SLX1K Semi-Soft Leather Camera Case
# 3969    Transcend JetFlash V30-16 GB USB 2.0 Flash Drive
# 3970    Transcend JetFlash V30-16 GB USB 2.0 Flash Drive
# 3971    Transcend JetFlash V30-16 GB USB 2.0 Flash Drive
# Name: title, dtype: object

# %%
cleaned_data.columns
# Out:
# Index(['reviewerID', 'reviewerName', 'unixReviewTime', 'asin', 'style',
#        'reviewText', 'overall', 'domain', 'category', 'title', 'brand',
#        'date'],
#       dtype='object')

# %%
# Input writing

# %% [markdown]
# # cleaned_data trim more

# %%
#reset index
cleaned_data.reset_index(drop=True, inplace=True)

# %%
#drow the rows where the string '</span>' is written
cleaned_data = cleaned_data[~cleaned_data['style'].str.contains('</span>')]

# %%
# get the average length of the style column
cleaned_data['style'].str.len().mean()
# number of rows where the length of the style column is more than the average length
cleaned_data[cleaned_data['style'].str.len() > cleaned_data['style'].str.len().mean()] # 4981 rows
# drop rows where the length of the style column is more than the average length
cleaned_data = cleaned_data[cleaned_data['style'].str.len() <= cleaned_data['style'].str.len().mean()]
# replace all commas in the style column with empty space
cleaned_data['style'] = cleaned_data['style'].str.replace(',', '')

# %%
# see the category column where string inches is written
pd.set_option('display.max_colwidth', -1)
cleaned_data[cleaned_data['category'].str.contains('inches')]
# drop rows where string inches is written in the category column
cleaned_data = cleaned_data[~cleaned_data['category'].str.contains('inches')]
# Out:
# /var/folders/rq/1_3v65yd0yn38jrwqf85v40w0000gn/T/ipykernel_96134/2876926659.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
# replace the commas in the category column with empty space
cleaned_data['category'] = cleaned_data['category'].str.replace(',', '', regex=False)

# %%
# replace all commas in brand and title columns with empty space
cleaned_data['brand'] = cleaned_data['brand'].str.replace(',', '', regex=False)
cleaned_data['title'] = cleaned_data['title'].str.replace(',', '', regex=False)

# %%
# get the title average length
cleaned_data['title'].str.len().mean()
# see rows where the length of the title column is more than the average length
cleaned_data[cleaned_data['title'].str.len() > cleaned_data['title'].str.len().mean()][100:150]
# for these rows, truncate the title column to include only the string before the symbol -
cleaned_data['title'] = cleaned_data['title'].str.split('-').str[0]

# %%
# reset the index and drop the old index column
cleaned_data.reset_index(drop=True, inplace=True)

# %%
cleaned_data
# Out:
#           reviewerID                                   reviewerName  \
# 0     A1O97WKID9L3IA  Jeff Wignall
# 1     A3V1A3C9DTLPME  Peter Faden
# 2     A3963R7EPE3A7E  John Schar
# 3     A3IUW081KXD3PE  Reviewer
# 4     AZMY6E8B52L2T   JP
# ...             ...   ..
# 9850  A3NHUQ33CFH3VM  Citizen John
# 9851  A2UQIQUOAB47OT  DB "aspiring part time free lance consultant"
# 9852  A1S27P7KJO9I96  Eric A. Hofstetter
# 9853  A10Y058K7B96C6  midnight821
# 9854  A3VZH0PWLQ9BB1  Tom B.
#
#       unixReviewTime        asin  \
# 0     1410739200      B00000J1T1
# 1     1310774400      B00000J1T1
# 2     1271808000      B00000J1T1
# 3     1321228800      B00000J1U5
# 4     1350691200      B00000J1EQ
# ...          ...             ...
# 9850  1405555200      B00KSRV3UQ
# 9851  1405814400      B00KSRV3UQ
# 9852  1405468800      B00KSRV3UQ
# 9853  1405555200      B00KSRV3UQ
# 9854  1404950400      B00KSRV3UQ
#
#                                                                                                                                style  \
# 0     Color:  Blue
# 1     Color:  Blue
# 2     Color:  Blue
# 3     Style:  VideoLink Powerline Internet
# 4     Size:  1-Pack
# ...             ...
# 9850  Fully Stainless Steel Holds 1000ml or 34oz Dishwasher Safe Double wall feature keeps liquids hot longer Elegant Brushed Finish
# 9851  Fully Stainless Steel Holds 1000ml or 34oz Dishwasher Safe Double wall feature keeps liquids hot longer Elegant Brushed Finish
# 9852  Fully Stainless Steel Holds 1000ml or 34oz Dishwasher Safe Double wall feature keeps liquids hot longer Elegant Brushed Finish
# 9853  Fully Stainless Steel Holds 1000ml or 34oz Dishwasher Safe Double wall feature keeps liquids hot longer Elegant Brushed Finish
# 9854  Fully Stainless Steel Holds 1000ml or 34oz Dishwasher Safe Double wall feature keeps liquids hot longer Elegant Brushed Finish
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   reviewText  \
# 0     This cable worked out well for me and is a very heavy-duty cable. I was having trouble with wifi on a new Mac Mini and decided to wire it directly to the router. I don't know why, but the Mini just wasn't getting good wifi even though it sits next to the router, but I still needed the router for my laptop and other misc stuff like a blu ray player, so I just used an extra ethernet port in the router and wired the Mini directly--it solved the problem (if you do this, be sure to tell the item that you are hardwiring to shut off the wireless).\n\nWorks great, nice to solve a problem so cheaply and easily.
# 1     I have never bought a Belkin product i wasn't satisfied with. This is no exception. Not that i really give this cord any thought now that it's in use, but that is the point, isn't it? I guess the only other thing to say, is that being blue, it's easy to find in the mass of cords around my TV and computer area.
# 2     I'll make this short and fast much in the same way this cable works.  First and foremost:  it works and works well.  It may be only be 3 feet long and that is totally my fault but it fits exactly as I need it.  If I were lucid when I measured the location I would have chosen a longer cord and had a little extra but for what I needed at the time and now the length is perfect.  I have a virtual cable factory behind my electronics and when making any changes it is a nightmare because it seems as if everyone will get hung up at the connector but NOT this Belkin.  It is snagless and that is fantastic for the lazy or impatient.  Those elements alone would be worth buying this cable; however, when the value is added in this is a fantastic buy and I highly recommend it under any circumstances that work.
# 3     * The setup is as short and simple as the instructions.\n* My wireless capable TV connected to the internet as soon as I selected the wired network setting.\n* Streaming a movie was not what I expected. The video had to re-buffer frequently. I never had this problem using my 802.11g wireless connection.\n\nIt is important to note that the instructions say, "Do not plug unit into a power strip." I only have one outlet near my router, and there is a similar Netgear device occupying that outlet. The Netgear device has an outlet so you don't lose an outlet when using this device. I had to plug the Belkin into the Netgear. This is probably violating the "No power strip rule". I also was not using the encryption option.
# 4     Currently I'm moving some family memories from older VHS tapes to DVD-Ram and ripping them to a digital format on my PC.  Since these are important memories, I want to have as many backups as possible so rerecording them back onto 'fresh' VHS tapes is something important to me.  Comparing these tapes to local price, the price here on Amazon is very competitive.  After recording older footage onto these VHS tapes, I'm quite satisfied with the quality of these tapes on the SP record setting.  Not much has changed in the VHS tape since it has become such a dinosaur, but it's great to be able to get this product when you need it, for a reasonable price.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# 9850  I think this is an improvement over the many stainless steel French presses I've had. It's stainless steel so it can take some rough treatment and not break. That's huge, that alone.It is easy to wash and can be placed in the dishwasher.It looks like a percolator almost, but it's a real French press. I think this model is the better of the two by the same company, because it has so much stability.
# 9851  Great contemporary design from Francois et Mimi, fantastic quality and value.  Works great and large enough to serve several.  We love Francois et Mimi products! Highly recommended.
# 9852  Makes a perfectly fine cup of french press coffee.  Like the stainless steel &#34;look.&#34;  I like how easy it is to clean up with stainless steel.  I have no issues whatsoever.  I'd purchase this AGAIN for sure.  I would purchase this as a gift for a coffee lover as well!
# 9853  In a world of bigger is better coffee pots, teh Francois et Mimi Brushed Stainless Steel French Coffee Press is a sight for sore eyes.  Whether you are a huge coffee drinker or just grab a cup on occasion, a press still might be for you.  This is actually my second press and the ease and convenience is a great selling point.  But it always makes great coffee.  :)This is great as it takes up very little counter space or can be easily taken with you (camping, for instance).  It's a beautiful design, very sleek and modern.  The construction quality is very good and durable.  The press has a tight &#34;seal&#34; and you do not get grounds in your coffee.  Overall, I'm very pleased and much happier with this press than I am a coffee pot that is 3-4 times its size.
# 9854  This is a great press. Attractive, does the job, sturdy, and keeps coffee warmer.This is my 5th press I've owned. I currently am down to 3, including this one. The glass ones tend to get broken over time, so this is great because there are no pieces to break.The lid and press parts fit tight, without leaking.  It's insulated, so it keeps your coffee warmer longer. It also looks nice. Took this camping, so we could still have good coffee while on the road.I'm staying with stainless presses from now on.
#
#       overall domain                 category  \
# 0     5.0      elect  Cat 5 Cables
# 1     5.0      elect  Cat 5 Cables
# 2     5.0      elect  Cat 5 Cables
# 3     4.0      elect  Computer Cable Adapters
# 4     5.0      elect  Blank Media
# ...   ...        ...          ...
# 9850  5.0      home   French Presses
# 9851  5.0      home   French Presses
# 9852  5.0      home   French Presses
# 9853  5.0      home   French Presses
# 9854  5.0      home   French Presses
#
#                                                  title             brand  \
# 0     Belkin CAT5e 3                                    Belkin
# 1     Belkin CAT5e 3                                    Belkin
# 2     Belkin CAT5e 3                                    Belkin
# 3     Belkin 8                                          Belkin
# 4     Maxell STD                                        Maxell
# ...          ...                                           ...
# 9850  Francois et Mimi Stainless Steel Double Wall Fre  Francois et Mimi
# 9851  Francois et Mimi Stainless Steel Double Wall Fre  Francois et Mimi
# 9852  Francois et Mimi Stainless Steel Double Wall Fre  Francois et Mimi
# 9853  Francois et Mimi Stainless Steel Double Wall Fre  Francois et Mimi
# 9854  Francois et Mimi Stainless Steel Double Wall Fre  Francois et Mimi
#
#            date
# 0    2017-04-13
# 1    2017-04-13
# 2    2017-04-13
# 3    2002-06-01
# 4    1999-09-04
# ...         ...
# 9850 2014-06-06
# 9851 2014-06-06
# 9852 2014-06-06
# 9853 2014-06-06
# 9854 2014-06-06
#
# [9855 rows x 12 columns]

# %% [markdown]
# # Input writing

# %%
import pandas as pd
import numpy as np
def sample_five_rows(reviewer_id, df, domains):
    sampled_rows = []
    for domain in domains:
        domain_specific_df = df[(df['reviewerID'] == reviewer_id) & (df['domain'] == domain)]
        n_samples = min(2, len(domain_specific_df))
        domain_df = domain_specific_df.sample(n=n_samples, random_state=3)
        sampled_rows.append(domain_df)
    return pd.concat(sampled_rows)
# Filter: to only include reviewerIDs that appear at least 1 time in each domain
reviewer_counts = cleaned_data.groupby(['reviewerID', 'domain']).size().unstack(fill_value=0)
valid_reviewer_ids = reviewer_counts[(reviewer_counts['elect'] >= 1) & (reviewer_counts['clothes'] >= 1) & (reviewer_counts['home'] >= 1)].index
# Randomly select 5 unique reviewerIDs
selected_reviewer_ids = np.random.choice(valid_reviewer_ids, size=5, replace=False)
domains = ['elect', 'clothes', 'home']
sampled_dfs = []
for reviewer_id in selected_reviewer_ids:
    sampled_df = sample_five_rows(reviewer_id, cleaned_data, domains)
    sampled_dfs.append(sampled_df)
subset_df = pd.concat(sampled_dfs)
# Reset the index and drop the old index column
subset_df.reset_index(drop=True, inplace=True)

# %%
#remove rows where description, title, style, brand, and feature are empty or null or nan
subset_df = subset_df[subset_df['title'].notna()]
subset_df = subset_df[subset_df['title'].notnull()]
subset_df = subset_df[subset_df['title'] != '']
subset_df = subset_df[subset_df['style'].notna()]
subset_df = subset_df[subset_df['style'].notnull()]
subset_df = subset_df[subset_df['style'] != '']
subset_df = subset_df[subset_df['brand'].notna()]
subset_df = subset_df[subset_df['brand'].notnull()]
subset_df = subset_df[subset_df['brand'] != '']

# %% [markdown]
# subset_df

# %%
import json

def generate_reviewer_text(df):
    df['reviewerName'].fillna(df['reviewerID'], inplace=True)  
    if df['date'].dtype != 'datetime64[ns]': # if the date column is not in datetime format
        df['date'] = pd.to_datetime(df['date'])
    reviewer_texts = []
    # Group by reviewer and iterate over each group
    for reviewer, group in df.groupby('reviewerID'):
        # Sort the group by date
        group = group.sort_values(by='date')       
        reviewer_name = group['reviewerName'].iloc[0]
        items_bought = ', '.join([brand + ' ' + title if brand != title.split(' ')[0] else title for brand, title in zip(group['brand'], group['title'])])       
        categories = ', '.join(group['category'])    
        styles = ', '.join(group['style'].astype(str))
        # Get the longest review text
        longest_review = group.loc[group['reviewText'].str.len().idxmax(), 'reviewText']
        # the text for a reviewer
        text = f"I am {reviewer_name}.\n"
        text += f"I bought the following products: {items_bought}.\n"
        text += f"These products are under the following categories respectively: {categories}.\n"
        text += f"Here are some features of these products respectively: {styles}.\n"
        text += f"For one of the products I bought, I wrote this comment: {longest_review}"
        text = text.replace('\n\n', '\n')
        # a dictionary for each text output
        reviewer_text = {
            "instruction": "Given the products I bought and my comments below, recommend to me what I should buy next.",
            "input": text,
            "output": ""
        }
        reviewer_texts.append(reviewer_text)
    return reviewer_texts

try:
    with open('reviewer_texts.json', 'r') as json_file:
        existing_data = json.load(json_file)
except FileNotFoundError:
    existing_data = []
reviewer_texts = generate_reviewer_text(subset_df)
existing_data.extend(reviewer_texts)

#combined results to the JSON file
with open('reviewer_texts.json', 'w') as json_file:
    json.dump(existing_data, json_file, indent=4)
with open('reviewer_texts.json', 'r') as json_file:
    loaded_texts = json.load(json_file)
# print the texts
for text in loaded_texts:
    print(text["input"])
    print("---------------------------------------------")
    print()
# Out:
# I am Buffy.
# I bought the following products: SCI Scandicrafts  Scandicrafts Ceramic Measuring Spoons , Verbatim DVD+R DL 8.5GB 8X Surface , Symphonized NRG Premium Genuine Wood in, instecho Digital Luggage Scale .
# These products are under the following categories respectively: Spoons, DVD+R Discs, Earbud Headphones, Luggage Scales.
# Here are some features of these products respectively: Measure in sizes of .25 tsp .5 tsp 1 tsp and 1 tbsp Made of Porcelain Dishwasher Safe, Style:  30-Disc, Color:  Red, Color:  Black.
# For one of the products I bought, I wrote this comment: I enjoy these spoons because they have lots of style, they're attractive and unique. Since they can break, I use them carefully.
# ---------------------------------------------
#
# I am SR.
# I bought the following products: Belkin 6, OXO Oxo SteeL Kitchen Tool and Utensil Rack, Opsales Polarized Bronze Metal Clip On Flip Up Brown Sun, Opsales Polarized Bronze Metal Clip On Flip Up Brown Sun, Hamilton Beach Hamilton Beach 2, AUKEY USB Hub 3.0 .
# These products are under the following categories respectively: Surge Protectors, Utensil Organizers, Sunglasses, Sunglasses, Toasters, Hubs.
# Here are some features of these products respectively: Size:  8 Feet Style:  Standard, Convenient storage for OXO SteeL OXO GOOD GRIPS or other tools Holds six tools Easy to install with included hardware, Size:  64 x 56mm Color:  Gray, Size:  50 x 35mm Color:  Gray, Smudgeproof brushed finish Versatile functions-cancel bagel and defrost buttons Cool touch exterior Auto shutoff Extra-wide slots, Color:  Silver.
# For one of the products I bought, I wrote this comment: Perfect for me.  Have two now.  One for my entertainment center, and another used for my Apple MacMini computer, and so far very pleased with them.  Used to have a UPS, but now days this product will do me just fine.  Portable, easy set up to boot.
# Edit:  Three (3) years old now, and time for another.  Live in Florida with lightning strikes a plenty.  Still seems to work with my entertainment center but concerned that some spikes may still get through.
# ---------------------------------------------
#
# I am Go Blue 99.
# I bought the following products: Trudeau Garlic Press , Dr. Oetker Dr. Oekter 1586 Leak Proof Springform Comfort Pa, Case Logic Case Logic Sleeve for 9, Babiators Original Aviator Sunglasses , Ubiquiti Networks Ubiquiti Unifi Ap.
# These products are under the following categories respectively: Garlic Presses, All Pans, Sleeves, Sunglasses, Wireless Access Points.
# Here are some features of these products respectively: It is self-cleaning Chrome plated It is dishwasher safe 5 years warranty, Leak-proof springform pan by dr. oekter Features 2 bases in 2 colors Excellent non-stick surface for easy release, Color:  Black/gray, Size:  Small (0-2 years) Color:  Galactic Gray, Color:  AP-AC LR Wireless Access Point.
# For one of the products I bought, I wrote this comment: We are big bakers in our household, but have never made any cheesecakes.  So I was excited to try out this 10" spring form pan from Dr. Oetker.  Dr. Oetker is apparently a popular brand in Europe that is trying to gain a foothold in the American market (you can see that the packaging has very little English on it).I immediately found a recipe for a Pumpkin Cheesecake, and we baked it using this pan.  The pan worked perfectly as there was no leaking.  The pan came apart easily and the cheesecake was fantastic.  The pan was easy to clean as well.  It seems durable and I like the paint color.We look forward to making plenty of cheesecakes and flourless cakes using this spring form pan.
# ---------------------------------------------
#
# I am Hiawhatha.
# I bought the following products: Fujifilm FinePix XP10 12 MP Waterproof Digital C, Evriholder Products Sweet Bytes Crust Cutter , Medline MDT13WHT2E Ladies' Full Length Lab Coat , Honey-Can-Do Honey, Mercer Culinary Mercer Culinary M60010WHM Millennia Men's Cook J, Sony HTCT390 Ultra.
# These products are under the following categories respectively: Point & Shoot Digital Cameras, Cookie Cutters, Lab Coats, Baking Cups, Chef Jackets, Speakers.
# Here are some features of these products respectively: Color:  Green, Heart crust cutter, Size:  Medium Color:  White, Oven safe to 500-degrees Freezer safe to -58-degrees Microwave safe, Size:  Large Color:  White, Style:  Sound bar.
# For one of the products I bought, I wrote this comment: I am not a professional photographer. So all I am looking for is a quick, fun, point and shoot to take with me to the beach. My husband found this at Costco for a great price so we grabbed it and took it along to the beach.
# It was a great camera to have poolside, to capture silly shots of our kids, our pets and each other playing in the pool. My husband and daughter had a great time taking those "just plunged into the water" shots, although it took us about 5 minutes to get the timing right with the shutter.
# It never let us down as far as battery life, uploading photos to the computer, and ease of use. I will say that the viewing screen is useless in the sunshine, as we couldn't see if our shots were coming out or not.
# But all in all we are happy with our vacation photos!
# ---------------------------------------------
#
# I am G. Hearn.
# I bought the following products: Rubbermaid L3, StarTech StarTech.com 10 ft Certified DisplayPort 1.2 Cab, Honeywell Oliver 16" PVC Puncture, Belkin 6, ZIPIT Grillz Backpack for Kids .
# These products are under the following categories respectively: Ice Cube Molds & Trays, DVI Cables, Shoes, HDMI Cables, Kids' Backpacks.
# Here are some features of these products respectively: Rubbermaid #2879-RD-PERI 2PK Ice Cube Tray^RUBBERMAID INC, Style:  Standard, Size:  Size-10, Size:  6 Feet, Color:  Camo Grey Style:  Extra Side Pocket.
# For one of the products I bought, I wrote this comment: This is certainly not a heavy-duty backpack, but it is a very reasonable duty backpack.  I have the Camo Gray backpack.  The teeth on the zipper pocket on the front are silver.  So when its unzipped, it looks almost like braces.  When its zipped, you cant see the teeth.  The pocket is not too deep, but certainly large enough for pencils, pens, and most phones.  The inside of this backpack is large and roomy.  Unfortunately there are no interior pockets.  There are what I would call water bottle pockets on each side.  The back is slightly padded, as are the shoulder straps.  A little more padding would have been nice.  I keep wondering if the hood, partially covering the back, is for anything.  Ive looked and looked, and I think its only as an accent to the backpack.  Made in China.
# ---------------------------------------------
#
# I am asiana.
# I bought the following products: Calphalon Gadgets Dual Edge Cheese Plane, BlueAvocado Deluxe Shopping Kit , Bang & Olufsen Bang &amp; Olufsen Beoplay H6 Over, Denon HEOS 7 Wireless Speaker  Compatible with A, Case Logic Case Logic LARI115 15" Ruck Sack Backpack .
# These products are under the following categories respectively: Graters, Lunch Boxes, Over-Ear Headphones, Wireless Multiroom Systems, Casual Daypacks.
# Here are some features of these products respectively: Features additional blade for cutting cheese blocks Super soft control zone Dishwasher safe Lifetime warranty, 4-piece kit that can hold up to 70 pounds Machine washable Collapsible, Color:  Black, Color:  Black Style:  HEOS 7, Color:  Hudson.
# For one of the products I bought, I wrote this comment: Although this Case Logic Ruck Sack which I received from Amazon is a different color than what is pictured on the website, I'm absolutely delighted with it and actually like the olive green color more than what was pictured.  The thick padding makes me know my laptop is secure and although I don't have a tablet, the fact that once I do get one, there's room for it, is a plus..  The front pocket, which has a zipper, allows easy access easy to a few items stored therein, while the drawstring, which is under the lid, keeps whatever I put therein secure.  This backpack is so attractive that although it allows for putting sneakers outside of the pack, I think it would take away from the overall look and so I won't do that.  This is a backpack that I'm really happy to own!
# ---------------------------------------------
#
# I am JEFF SMITH "Jeff Smith".
# I bought the following products: Blue Moon Beads Blue Moon Fine Cable Chain , Mediabridge 3.5mm Male To Male Stereo Audio Cabl, Travelon Set Of 2 Luggage Tags Hot Spots Assorte, AmazonBasics Mini DisplayPort  to HDMI Adapter.
# These products are under the following categories respectively: Posters & Prints, Stereo Jack Cables, Luggage Tags, Connectors & Adapters.
# Here are some features of these products respectively: Manufacturer: Blue Moon Beads(R) Quantity: 1 Size: 100 Inch Color: Gold Composition: Sterling Plated, Color:  8 Feet, Size:  One Size Color:  Assorted, Style:  Adapter.
# For one of the products I bought, I wrote this comment: This is what Apple Store suggested I buy and install. I did but it didn't!
# (Believed what a guru told me about plugging this into a second display. It didn't.
# So, followed the next guy's suggestion and it didn't work either. Took it into the
# tech guys at Apple Store, their setup worked and they suggested I could buy it
# online, so did, but it didn't! Work that is.) That gives you the whole story!
# So, I'm going to buy the more expensive model and see if that works. Maybe I just
# can't add a second display (Samsung) to my iMac. Still open for advice.
# ---------------------------------------------
#
# I am Hiawhatha.
# I bought the following products: Fujifilm FinePix XP10 12 MP Waterproof Digital C, Evriholder Products Sweet Bytes Crust Cutter , Medline MDT13WHT2E Ladies' Full Length Lab Coat , Honey-Can-Do Honey, Mercer Culinary Mercer Culinary M60010WHM Millennia Men's Cook J, Sony HTCT390 Ultra.
# These products are under the following categories respectively: Point & Shoot Digital Cameras, Cookie Cutters, Lab Coats, Baking Cups, Chef Jackets, Speakers.
# Here are some features of these products respectively: Color:  Green, Heart crust cutter, Size:  Medium Color:  White, Oven safe to 500-degrees Freezer safe to -58-degrees Microwave safe, Size:  Large Color:  White, Style:  Sound bar.
# For one of the products I bought, I wrote this comment: I am not a professional photographer. So all I am looking for is a quick, fun, point and shoot to take with me to the beach. My husband found this at Costco for a great price so we grabbed it and took it along to the beach.
# It was a great camera to have poolside, to capture silly shots of our kids, our pets and each other playing in the pool. My husband and daughter had a great time taking those "just plunged into the water" shots, although it took us about 5 minutes to get the timing right with the shutter.
# It never let us down as far as battery life, uploading photos to the computer, and ease of use. I will say that the viewing screen is useless in the sunshine, as we couldn't see if our shots were coming out or not.
# But all in all we are happy with our vacation photos!
# ---------------------------------------------
#
# I am R.E. Burke.
# I bought the following products: EVS Sports EVS Sports GB BEANIE Sweat Beanie , KitchenAid Silicone Spoon Spatula , Granite Ware Granite Ware 0713, Mediabridge USB 2.0 , Neewer 750II TTL Flash Speedlite with LCD Displa.
# These products are under the following categories respectively: Skullies & Beanies, Spatulas, Kitchen & Dining, USB Cables, Shoe Mount Flashes.
# Here are some features of these products respectively: Size:  One size fits most Color:  Black, Durable ergonomic handle Dishwasher safe, Made in USA 9-inch Diameter Designed for easier drainage Perfect for canning preparation Dishwasher safe, Capacity:  10 Feet, Style:  Flash.
# For one of the products I bought, I wrote this comment: In general, this cable is a very good value and is serving me reasonably well as a USB extension for my iPad2, one that makes charging and syncing much more convenient. The construction quality of the cable itself is very good.
# However, the connectors have been something of a problem for me. One connector was slightly misaligned and had to be bent back into shape when it arrived. This shouldn't be too much of a problem in the future unless I have to repeatedly connect and disconnect the cable, in which case I might need to keep correcting the alignment. The other connector fits a bit loosely into the USB port on my computer, and I occasionally have to jog it to get a proper connection.
# If these problems show themselves to be corrected with time, then I will upgrade my rating to four or five stars.
# ---------------------------------------------
#
# I am Steve B "Mac User".
# I bought the following products: Jaccard Simply Better Meat Tenderizer Knife 45 B, SE JT6221 16, Logitech Z623 400 Watt Home Speaker System , Kingston Technology Kingston HyperX Impact Black 16GB Kit  1866MHz D.
# These products are under the following categories respectively: Tenderizers, Repair Tools & Kits, Speakers, Memory.
# Here are some features of these products respectively: Reduce cooking time by up to 40% More even cooking Reduced shrinkage No loss of natural juices Easy clean-up, Size:  16-Piece Color:  Blue, Style:  Analog, Capacity:  16 GB kit.
# For one of the products I bought, I wrote this comment: I like the stainless steel columns for the added stability over plastic, and the easy disassembly is nice for cleaning, but watch out when reassembling. Many of my blades were not aligned with the others and reassembly was impossible until I mucked around bending blades back into alignment. Even when aligned, assembly required patience and care. Even if you never disassemble it, it's still a very effective tenderizer, and it makes marinating more efficient. Using this tool is an effective way to make lower-end cuts as tender as the high-priced ones.
# ---------------------------------------------
#
# I am Charlemange.
# I bought the following products: Ekco  EKCO Pao! 8 Piece Complete Bamboo Tool Set, MediaDevil Stylus  for Tablets &amp; Smartphones, Ergodyne N, Xtratuf XTRATUF Sharkbyte Men’s Nubuck Leather Deck Shoe, Francois et Mimi Francois et Mimi Bamboo Multi, iHome iBT12SC Rechargeable Flask Shaped Bluetoot.
# These products are under the following categories respectively: Kitchen Utensils & Gadgets, Styluses, Balaclavas, Loafers & Slip-Ons, Breakfast Trays, Portable Bluetooth Speakers.
# Here are some features of these products respectively: Manufactured to the Highest Quality Available. Design is stylish and innovative. Satisfaction Ensured. Great Gift Idea., Color:  Black, Color:  Black, Size:  10 Style:  Women's, Tray measures 21.5" by 13.75" Adjustable Legs Contains convenient drawer Made of thick and sturdy Bamboo Eco-Friendly, Color:  Silver.
# For one of the products I bought, I wrote this comment: The iHome iBT12SC Rechargeable Flask Shaped Bluetooth Stereo Speaker is a cool looking novel item for a speaker. Sound quality is pretty good for as small as it is. I found recharge time to be about 30 minutes to an hour and got about 3 to 5 hours of play time depending on how much volume I was listening to my music at.
# Would I carry this around listening to music even though it comes with a nice carrying case with embossed, play, skip and stop buttons on the top?
# Probably not.
# This speaker is again for someone who wants something different and looks to go with it. I gave it three stars because it looks cool and sounds good but use time was a little on the short side and the volume level was not as loud I would have liked.
# ---------------------------------------------
#
# I am Cabushka.
# I bought the following products: Belkin  Belkin BZ103050, Charles Viancin Charles Viancin Honeycomb Pot Holder , Travelon Set of 2 Luggage Tags , Bose SoundLink On, Thunder Group Thunder Group 24 Cup Nonstick Muffin Pan.
# These products are under the following categories respectively: Power Strips, Potholders, Luggage Tags, Over-Ear Headphones, Muffin & Cupcake Pans.
# Here are some features of these products respectively: Style:  2.1 Amp, Can be used as a pot holder and trivet Useful tool for unscrewing tight jar lids Slow heat transfer Dishwasher safe Food grade silicone, Color:  Assorted, Color:  Black, Thunder Group SLKMP024 Carbon Steel Non Stick Muffin Pan.
# For one of the products I bought, I wrote this comment: Finally a comfortable headphone that I can wear for hours! This is my first experience with Bose headphones and I'm very impressed. Though there is most definitely a sacrifice in carry-on convenience, these would have been wonderful on my recent flight to & from Europe. I could hardly make it through a movie wearing my painful in-ear buds. The Bluetooth feature is awesome while at home, giving me freedom of movement while listening to music, books or podcasts. There is also an auxiliary cord for use on flights or non-Bluetooth situations. The sound is very clear and controls are strategically placed. Definitely worth the increase in size for the comfort and clarity!
# ---------------------------------------------
#
# I am Sasha Q..
# I bought the following products: Seagate Backup Plus 1TB Portable External Hard D, Seagate Wireless Plus 1TB Portable Hard Drive wi, Francois et Mimi Francois et Mimi Double Wall French Coffee Press, Mercer Culinary Mercer Culinary M60010WHM Millennia Men's Cook J.
# These products are under the following categories respectively: Data Storage, External Hard Drives, French Presses, Chef Jackets.
# Here are some features of these products respectively: Color:  Black Capacity:  1 TB, Capacity:  1 TB, Stainless Steel Holds 350mL or 12oz Dribble-proof spout Dishwasher Safe Double wall feature keeps liquids hot longer, Size:  Large Color:  White.
# For one of the products I bought, I wrote this comment: I am used to the Bodum Coffee Presses, and I like the beauty of this one, especially when serving guests (although its size does limit the amount of people it can serve at one time!). Mine arrived in great condition, though the box did have a hole in it, at least the press was not damaged or scratched. It makes a great cup of coffee and I didn't detect any metallic taste. I like that, unlike the glass beakers, it is unbreakable. The price is reasonable, and it really is pretty. Plus, it makes a great cup of java and keeps it hot for awhile, too (although you might get a pretty strong cup of coffee if you keep it in the press for too long!). All in all, a good buy for a great coffee press. If they could get the packaging in better order, it would also make a great gift.
# ---------------------------------------------
#
# I am Catrine.
# I bought the following products: West Bend West Bend 82306 Stir Crazy 6, Baby Cakes 5 Waffle Stick Maker, iMBAPrice iMBAPrice&reg; 15 Feet Black USB 2.0 Printer and, Unknown One Decade Auto Rosary For Rear View Mirror , TASIRO Best Handmade Bling Bling Business Card H, AmazonBasics Portable Wireless Bluetooth Speaker.
# These products are under the following categories respectively: Popcorn Poppers, Waffle Irons, USB Cables, Pendants, Business Card Cases, Portable Bluetooth Speakers.
# Here are some features of these products respectively: Plastic Imported This product is highly durable The product is manufactured in China The product is easy to use, Bake 5 waffle sticks in a matter of minutes Non-stick coating Measuring cup included Two-pronged fork to remove waffle sticks Recipes included, Size:  10 Feet, Color:  Pink Imitation Marble Glass, Color:  silver gift set, Color:  Blue.
# For one of the products I bought, I wrote this comment: I love the stir crazy popcorn maker. This is the second one I purchased. My last one was used to death. I recently discovered "coconut oil" and its a great way to pop corn with this popper. The flavor is awesome. I use a 1/2 c. of kernels and 1-2 T. oil. Makes a perfect batch every time. I bought many different poppers,  as I do not like microwave popcorn. I got a much more expensive one and although it looked cute, it only made a small amt. It was also a real pain to clean. This is a nice size bowl. Clean up is a breeze. So easy! Do not hesitate. Use coconut oil & flavacol and you will have "Movie theater style" popcorn. They are both sold on amazon.com
# ---------------------------------------------
#
# I am Fredddd.
# I bought the following products: Foot Traffic Foot Traffic The Ultimate Footie , Trudeau 4, Quaker Tray Table Honey Oak 21&quot; X 15&quot; , Unknown Linksys Powerline AV 1, Sylvania 9.
# These products are under the following categories respectively: Socks, Salt & Pepper Shaker Sets, Folding Tables, Powerline Network Adapters, Portable DVD Players.
# Here are some features of these products respectively: Color:  Black and White (2 Pairs), 4-1/2-Inch salt and pepper shakers by Trudeau High gloss Perfect for the table Elegant design Lifetime warranty Note: Color may appear darker, 2 Pack 21" x 15" Laminated tops with no-spill molding Metal legs with matching non-mar tips Stain resistant - Oak parquet finish, Capacity:  200 Mbps, Color:  Pink.
# For one of the products I bought, I wrote this comment: -1 stars.
# Got this lovely pink dvd player for my granddaughter for Christmas.  A nice pink case to go with it.  The Disney Frozen movie, and several other movies.
# On Christmas day she opened it, a little while later wanted to play a movie.
# Nothing.
# Tried other dvd's, nothing.  Yes it was on, sometimes it would spin, but not recognize a dvd was in it.  I sent it back for refund.
# This company can not make up for the disappointment my grandchild, I and her parents went throught on Christmas day.
# I bought another no name pink one from a shopping channel, we'll see how it does.  Probably won't fit the case, but If it works, I'll find another case.
# This Sylvania had negative reviews............I should have listened!  P.S. the lid that opens to put the dvd in, is flimsy and cheap.
# SO DISAPPOINTED.
# ---------------------------------------------
#
# I am Charlemange.
# I bought the following products: Ekco  EKCO Pao! 8 Piece Complete Bamboo Tool Set, MediaDevil Stylus  for Tablets &amp; Smartphones, Ergodyne N, Xtratuf XTRATUF Sharkbyte Men’s Nubuck Leather Deck Shoe, Francois et Mimi Francois et Mimi Bamboo Multi, iHome iBT12SC Rechargeable Flask Shaped Bluetoot.
# These products are under the following categories respectively: Kitchen Utensils & Gadgets, Styluses, Balaclavas, Loafers & Slip-Ons, Breakfast Trays, Portable Bluetooth Speakers.
# Here are some features of these products respectively: Manufactured to the Highest Quality Available. Design is stylish and innovative. Satisfaction Ensured. Great Gift Idea., Color:  Black, Color:  Black, Size:  10 Style:  Women's, Tray measures 21.5" by 13.75" Adjustable Legs Contains convenient drawer Made of thick and sturdy Bamboo Eco-Friendly, Color:  Silver.
# For one of the products I bought, I wrote this comment: The iHome iBT12SC Rechargeable Flask Shaped Bluetooth Stereo Speaker is a cool looking novel item for a speaker. Sound quality is pretty good for as small as it is. I found recharge time to be about 30 minutes to an hour and got about 3 to 5 hours of play time depending on how much volume I was listening to my music at.
# Would I carry this around listening to music even though it comes with a nice carrying case with embossed, play, skip and stop buttons on the top?
# Probably not.
# This speaker is again for someone who wants something different and looks to go with it. I gave it three stars because it looks cool and sounds good but use time was a little on the short side and the volume level was not as loud I would have liked.
# ---------------------------------------------
#
# I am Bookenator.
# I bought the following products: Winco Winware Stainless Steel Dredges 10, Francois et Mimi Francois et Mimi Double Wall Conical Top French , Honeywell Oliver 45 Series 8" Leather Composite Toe Waterp, Logitech FOCUS Flexible Any, ZAGG Slim Book Ultrathin Case .
# These products are under the following categories respectively: Cooking Dredges, French Presses, Industrial & Construction Boots, Cases, Keyboard Cases.
# Here are some features of these products respectively: 10-Ounce capacity Seamless stainless steel design With handle Professional quality, Stainless Steel Holds 1000ml or 34oz Dribble-proof spout Dishwasher Safe Double wall feature keeps liquids hot longer, Size:  10 Style:  Black 6-Inch, Color:  Black, Size:  iPad Mini 2 / 3.
# For one of the products I bought, I wrote this comment: Oh so close to 5 stars, but not quite. My grandmother had a very similar shaker and when we were kids we would sprinkle powdered sugar on just about everything with it. Well, I decided to find a similar shaker so my kids could enjoy the same "snow storm" of sugar once in a while. (Hey kids, go easy on the sugar!). This looks and feels exactly like the one grandma used to have, with one small complaint. If you over tighten the lid, it will pop off, and if you under tighten the lid, it will pop off. You have to get it just right. Fortunately, it's not like you're opening and closing it that often. Open, fill, tighten, and you're off to the races. The powdered sugar races.For the price I'm happy with what I got, and the kids are going to love it.
# ---------------------------------------------
#
# I am A2W9I628I6SE1U.
# I bought the following products: OXO SteeL Can Opener, Church 540OR 346 Toilet Seat with Oil Rubbed Bro, Logitech Wireless Mouse M325 with Designed, PNY Elite Performance 16GB High Speed SDHC Class, Five Star Five Star Backpack .
# These products are under the following categories respectively: Manual, Packing Organizers, Mice, SD Cards, Casual Daypacks.
# Here are some features of these products respectively: Big cushioned handles absorb pressure Oversized knob is easy to turn Sharp cutting wheel Built-in bottle cap opener Hand wash only, Color:  Blue flamingo, Color:  Purple, Capacity:  64 GB, Color:  Dark Gray.
# For one of the products I bought, I wrote this comment: I've used many can openers. OXO's SteeL is the best manual I've ever worked with. It locks onto lids without hassle and smoothly opens them with a minimum of effort. The rounder, ergonomic turning knob sets it apart from your standard fare of openers and it just seems much easier to turn. I've yet to find a can that it can't handle. It even goes through large 5 lb tomato cans from the value clubs with no fuss.Hand washing clean-up is as easy as it gets, and I prefer it to any electric that I've tried. The stainless steel finish is still holding up beautifully after over a year of nearly daily use. Our electric can opener resides in storage now. This is a good one folks!~ Kort
# ---------------------------------------------
#
# I am Ms. Poodie.
# I bought the following products: Maxell 109085 Brick Packs Optimally Designed for, BigKitchen Bene Casa Aluminum Oil Strainer , Bickmore Ultra, Winco Winware Stainless Steel Dredges 10, GreatShield EX Series 2 in 1 Ballpoint Pen and C.
# These products are under the following categories respectively: Data Cartridges, Food Strainers, Baseball Caps, Cooking Dredges, Styluses.
# Here are some features of these products respectively: Size:  1 PACK, Aluminum with convenient pouring spout Separates impurities from oil Lid secures contents and enables you to reuse oil Dishwasher safe, Color:  Dark Hat Brush, 10-Ounce capacity Seamless stainless steel design With handle Professional quality, Color:  Black.
# For one of the products I bought, I wrote this comment: I am happy with the performance of this item. It is a perfect fit on my stove top and will take the place of me using empty 11oz coffee cans and vegetable cans for this. After it cools I will place in fridge, invert and put in double plastic grocery bag, tie off and dispose in trash.
# ---------------------------------------------
#
# I am Dennis &amp; Veronica.
# I bought the following products: Boogie Board Boogie Board 8.5, STORMTRACKS 11714.06 Youths' Boot , Happy Sales Happy Sales HSST, Ergodyne N, gofanco Pro.
# These products are under the following categories respectively: Graphics Tablets, Boots, Paring Knives, Balaclavas, HDMI-to-VGA Adapters.
# Here are some features of these products respectively: Color:  Black, Size:  Size 08 Color:  Black/Tan, Made in Japan Blade Length: 3.5" Blade 8 7/8". overall Resist Rust Stain Free Dishwasher-safe and Very Easy to Re-Sharpen, Color:  Black, Style:  Micro HDMI to VGA with Audio Support.
# For one of the products I bought, I wrote this comment: This knife has a comfortable handle and is lite.  It is very sharp, which is why the scabbard not staying on is such a problem for me, hence the 3 stars.  The sheath has a nub at the top, making you think that this is some sort of release for it but it actually doesn't do anything.  Found a bunch of these in my local Asian market the other day for a similar price as on here.  All versions were under $10 in the store.
# ---------------------------------------------
#
# I am R. Eye.
# I bought the following products: Bodum Canteen 6, Thule EnRoute Strut Daypack for 15, Mercer Culinary Mercer Culinary M60200BK7X Millennia Men's Cook , StarTech StarTech.com Thunderbolt 3 Cable .
# These products are under the following categories respectively: Tea Strainers & Filters, Backpacks, Casual Button-Down Shirts, USB Cables.
# Here are some features of these products respectively: Canteen Double Wall Glass and Glass Filter Borosilicate Glass Clear Dishwasher Safe No warranty, Color:  Cobalt, Size:  Medium Color:  Black, Color:  20Gbps - White Capacity:  6 ft / 2m.
# For one of the products I bought, I wrote this comment: The Bodum Canteen 6 ounce is nice in that it is glass and double walled so no metal to contaminate tea flavor and no burned fingers but the filtering mechanism consists of slits studded around the lower sides of the base of the inner cup that are large enough to allow some tea leaf particles to escape.  Some reviewers didn't mention this so perhaps the clarity of the steeped tea depends on the type of loose tea leaves one buys.  Also, it makes about one china teacup of tea - OK if you are a china teacup tea sipper but if you want a big mug of tea you will need to perform the steeping procedure twice.  This would be nice for loose tea enthusiasts at work who wish to dispense with an extra mug/teacup as you can drink the tea from the outer double walled glass collector.
# ---------------------------------------------
#
# I am Citizen John.
# I bought the following products: OXO SteeL Can Opener, Logitech Z623 400 Watt Home Speaker System , Audio-Technica Audio, Francois et Mimi Francois et Mimi Stainless Steel Double Wall Fre, Wells Lamont Men's Leather Winter Gloves .
# These products are under the following categories respectively: Manual, Speakers, Computer Accessories & Peripherals, French Presses, Cold Weather Gloves.
# Here are some features of these products respectively: Big cushioned handles absorb pressure Oversized knob is easy to turn Sharp cutting wheel Built-in bottle cap opener Hand wash only, Style:  Analog/Optical, style:  ATR2500-USB, Fully Stainless Steel Holds 1000ml or 34oz Dishwasher Safe Double wall feature keeps liquids hot longer Elegant Brushed Finish, Size:  Large Color:  Chestnut.
# For one of the products I bought, I wrote this comment: My favorite thing about this system is that with regard to my TV, it truly is plug-and-play. That simple. I merely plugged in the 3.5mm audio cable to the back of the TV and turned the sound on using the basic controls on one of the speakers.
# Of course, the sound beats my that of my TV so much that I feel dumb for relying on my TV's built-in speakers until now. I watched a soccer match and could hear the audience very well in addition to the announcers and whistles. Sounds in the audience were distinct - truly and surprisingly distinct, and that added a lot.
# It's easy to know why Logitech says this is a gaming quality speaker system. The bass is a good fit with the speakers in terms of pricing compatibility. It's a great set without busting one's budget.
# ---------------------------------------------
#
# I am Hervian Rose.
# I bought the following products: Honeywell Retail Honeywell Sync Stereo Earmuff with MP3 Connectio, Tupperware Thatsa Bowl HUGE BIG BOWL MEGA 42 Cup, MQbix MQET38WHT AeroFones Platinum High Performa, South Main Hardware South Main Hardware 848107 100.
# These products are under the following categories respectively: Earmuffs, Storage & Organization, Earpads, Cable Ties.
# Here are some features of these products respectively: Style:  Wireless, 42 Cup CAPACITY VIRTUALLY AIR TIGHT VIRTUALLY LIQUID SPILL PROOF SEAL Green Bowl with Parrot Green Seal, Color:  White, Color:  Natural Style:  100-Pack.
# For one of the products I bought, I wrote this comment: received for a wedding gift 19 years ago and my dear husband and I were able to melt it in the oven between us. He had just cut up about 10 pounds of cubed lamb and put a marinade on it. He stuck it in the cold oven to keep the dog from bothering it and went out to take kids to school.I came in from the garden with some squash to roast and turned on the oven while I was cutting it up.When the smoke alarm sounded we realized that our wonderful bowl was finished. We took a picture.So.This one is very similar. It is shaped a little differently but seems to have the same basic construction. If it lasts as long as the first, we'll be empty nested and probably won't need anything that big.
# ---------------------------------------------
#
# I am Mary Ann.
# I bought the following products: Mastrad Silicone Slim Spatula , Bake Porter Bake Porter Large Baking Sheet , Verbatim Wireless Mini Travel Optical Mouse , Xtratuf XTRATUF Legacy Series 12" Neoprene Men's Fishing, Kinmac Bohemian Pattern Lightweight 13 inch Lapt.
# These products are under the following categories respectively: Spatulas, Kitchen & Dining, Mice, Industrial & Construction, Sleeves.
# Here are some features of these products respectively: Heat resistant to 600 F Non-porous won't stain Hygienic dishwasher safe Won't scratch cookware Good for scaping small cans, Professional quality non-stick bakeware PTFE/PFOA Free Made from carbon steel Hand wash recommended, Color:  Red, Size:  10 Color:  Copper/Tan/Camo, Color:  Rose Capacity:  15 inch-15.6 inch.
# For one of the products I bought, I wrote this comment: This is a very nice spatula.  The handle is long enough to reach into deep bottles and cans.  It is all one piece, so there are no crevices to collect sticky things, and the head cannot clip off.  It is flexible enough to use with my Sunbeam Mixmaster mashing potatoes and mixing baked goods. A great addition to my gadgets.
# ---------------------------------------------
#
# I am Pro-gun.
# I bought the following products: Macally Full Size USB Wired Keyboard  for Mac an, inShang 360 Degrees Slim Rotating Stand Leather Case Cov, Softalk Black Phone Shoulder Rest with Microban , Thunder Group Thunder Group Stainless Steel Measuring Spoon .
# These products are under the following categories respectively: Keyboards, Cases, Shoulder Bags, Spoons.
# Here are some features of these products respectively: Style:  Wired USB, Size:  For iPad Mini 1st/2nd Color:  Hot Pink, Color:  Black, Thunder Group OW356 Stainless Steel Measuring Spoon Set.
# For one of the products I bought, I wrote this comment: Works great.  I previously had a beige one to match a beige phone but ordered a black one to match my new black phone.
# My only complaint is that the edge of the double stick tape is white and it shows when attached to the phone.  I had to pull mine off so I could color the edge with a black sharpie so it wouldn't stand out so much.  My recommendation to others, color the edge of the tape with a sharpie before attaching it to the phone!
# ---------------------------------------------
#
# I am Twinsboystwice.
# I bought the following products: Sunbeam FPSBHS0302 250, HDE Case for iPad 2 3 4 , Slive, Five Star Five Star Backpack .
# These products are under the following categories respectively: Stand Mixers, Cases, Radios, Casual Daypacks.
# Here are some features of these products respectively: 250 watt motor 5 speeds; heel rest design Chrome beaters and dough hooks Dual function Hand Mixer; Stand Mixer 3-quart stainless steel bowl, Color:  Blue, Color:  Green, Color:  Dark Gray.
# For one of the products I bought, I wrote this comment: This is a very interesting item. It comes with the self wind and 2 AAA battery options. The siren is loud, but not ear splitting. Radio works great, to my surprise.  It only took a few winds to get the light and radio going.  I like that it has a LED light. It is small, but does the trick.  It comes with a USB charger cable, that probably works with most cellphones, but does not work with my iPhone; you will need to use your own Lightning cable.  I was surprised at how small this is, about 3 inches by 5 inches and an inch thick. In my opinion, this is a good thing.  Easy enough to keep in your car or backpack.
# ---------------------------------------------
#
# I am Amazon Customer.
# I bought the following products: Thirstystone Set of 6 Cork Coasters from Thirstystone, ADATA A, Honeywell Servus SuperFit 12" PVC Dual, Mount-It! Mount.
# These products are under the following categories respectively: Coasters, USB Flash Drives, Industrial & Construction Boots, Computer & Monitor Mounts.
# Here are some features of these products respectively: Set of 6 Cork Coasters Included Offered By Thirstystone Made in the U.S.A., Size:  16GB Color:  Black, Size:  L (size 11-13 boots) Style:  Bagged, Size:  1 Monitor.
# For one of the products I bought, I wrote this comment: We had these back in the 1960's they were called artics. Back then they had metal clips instead of elastic cord . I'm not sure how well the cord will hold up. They are great for deep snow when your standard snow-boot just will not cut it. They fit some 10 1/2 inch shoes but not all. Sports type shoes don't fit but dress type do.
# ---------------------------------------------
#
# I am Plano Gal.
# I bought the following products: Coby CVE91WHT Isolation Stereo Earphones with Vo, Cobra Products Cobra Products 304 4, IKEA Ikea Travel Size Bottles 8 Pack , Lexar JumpDrive V30 64GB USB 2.0 Flash Drive .
# These products are under the following categories respectively: Earbud Headphones, Toilet Plungers & Holders, Travel Accessories, USB Flash Drives.
# Here are some features of these products respectively: Color:  Black, Clears Clogged Sinks 4-inch red rubber force cup 9-inch Wood Handle, Size:  Set of 8, Capacity:  64GB.
# For one of the products I bought, I wrote this comment: I have small ear canals and have been having discomfort with my earbuds, so tried these and about three other brands. These, so far are the most comfortable for me. The sound is good, and I like the volume control that is on the earphone wire. It has a little less "rustling" noise from movement than the other brands I have tried. I gave it a four star, because while I like them a lot, I still  hope to find something a tiny bit more comfortable and that has no rustling noise at all from the wires and movement.
# ---------------------------------------------
#
# I am Sean P. Logue "If you can't win, change the r....
# I bought the following products: OXO Good Grips 6, NETGEAR 8, Xtratuf XTRATUF Finatic II Men’s Leather Deck Shoes , iEGrow ZH222C Battery Charger for 3.7 V/3.8 V Li.
# These products are under the following categories respectively: Food Strainers, Switches, Shoes, Battery Chargers.
# Here are some features of these products respectively: Fine mesh for straining Sturdy stainless steel double rod construction Broad soft handle Dishwasher safe, Size:  08 Port | Hidden Cables Style:  Plastic Unmanaged, Size:  10 Color:  Chocolate, Size:  2-Bay Color:  ZH221C.
# For one of the products I bought, I wrote this comment: This is an absolutely perfect size.  It is not so big that you won't find a place to store it, but large enough to hold a bunch of angel hair pasta that would slip right out of the little holes in a traditional colander.  It also fits over the sink so that I can pour the pasta (or whatever I'm draining) right into it, water and all, and have the water drain into the sink.It doesn't say in the description, but this is a double weave strainer.  In other words, there are two layers of thin metal mesh to ensure even the smallest seeds and particles are caught in the net.It has a traditional soft black rubber Oxo handle, too.  This is important when using it over the sink as it keeps it from slipping around when the water hits it.Nice!
# ---------------------------------------------
#
# I am Hervian Rose.
# I bought the following products: Honeywell Retail Honeywell Sync Stereo Earmuff with MP3 Connectio, Tupperware Thatsa Bowl HUGE BIG BOWL MEGA 42 Cup, MQbix MQET38WHT AeroFones Platinum High Performa, South Main Hardware South Main Hardware 848107 100.
# These products are under the following categories respectively: Earmuffs, Storage & Organization, Earpads, Cable Ties.
# Here are some features of these products respectively: Style:  Wireless, 42 Cup CAPACITY VIRTUALLY AIR TIGHT VIRTUALLY LIQUID SPILL PROOF SEAL Green Bowl with Parrot Green Seal, Color:  White, Color:  Natural Style:  100-Pack.
# For one of the products I bought, I wrote this comment: received for a wedding gift 19 years ago and my dear husband and I were able to melt it in the oven between us. He had just cut up about 10 pounds of cubed lamb and put a marinade on it. He stuck it in the cold oven to keep the dog from bothering it and went out to take kids to school.I came in from the garden with some squash to roast and turned on the oven while I was cutting it up.When the smoke alarm sounded we realized that our wonderful bowl was finished. We took a picture.So.This one is very similar. It is shaped a little differently but seems to have the same basic construction. If it lasts as long as the first, we'll be empty nested and probably won't need anything that big.
# ---------------------------------------------
#
# I am OlyNomad.
# I bought the following products: Magic Chef Magic Chef MCD1311ST 1.3cf 1000W S, Homer Laughlin Fiesta 6, Honeywell Oliver 45 Series 8" Leather Composite Toe Waterp, Wells Lamont Men's Leather Winter Gloves , Monoprice Certified Premium HDMI Cable , Zebra Pen Zebra StylusPen Retractable Ballpoint Pen .
# These products are under the following categories respectively: Countertop Microwave Ovens, Utensil Crocks, Industrial & Construction Boots, Cold Weather Gloves, HDMI Cables, Computers & Accessories.
# Here are some features of these products respectively: Manufacturer: Magic Chef, Made in the USA Vitrified Ceramic body Lead-Free glaze Dishwasher Microwave and Oven safe 5-year chip resistance warranty, Size:  10 Style:  Brown 6-Inch, Size:  Large Color:  Chestnut, Color:  Black Style:  Premium, Style:  Orange Cream Barrel.
# For one of the products I bought, I wrote this comment: We've had ours less than two years and it's already stopped working.  Last night it started smelling like plastic parts were burning when we were cooking in it.  Before that it would turn off randomly.  Power supply was fine, it was the microwave itself.  Called their customer service to find out what options existed and the rep I got (after 20 minutes and a transfer) was extremely rude, answered with a monotone and said there was nothing they could do.  It literally felt like I was interrupting her from painting her nails or something, that same kind of blase tone.  The combination of the short life span of their product and their obvious lack of concern from their customer service guarantees I won't buy another Magic Chef product.
# ---------------------------------------------
#
# I am Paka Paka.
# I bought the following products: Bonavita BV4000ID Porcelain Immersion Coffee Dri, Honeywell Oliver 45 Series 8" Leather Composite Toe Waterp, Seagate NAS 2, QualGear Universal Dual Shelf Wall Mount for A/V.
# These products are under the following categories respectively: Coffee Machines, Industrial & Construction Boots, Network Attached Storage, TV Ceiling & Wall Mounts.
# Here are some features of these products respectively: Porcelain dripper with on/off switch Easy clean up 16 oz. brewing capacity Uses #4 paper filters Includes lid to maintain heat, Size:  10 Style:  Brown 6-Inch, Capacity:  8 TB Style:  4-Bay, Size:  2 Shelves.
# For one of the products I bought, I wrote this comment: I love this product, but as a regular tea drinker, it's a long time to wait for coffee. After you wait to heat the water and pour it in, you wait two minutes for it to steep. Then stir, and then wait another minute.  By the time you open the switch to release the water into the cup, the coffee is lukewarm.  So of course next time I will make sure I boil the water fully!  Then, as a non-coffee drinker, I didn't know how much ground coffee to put in, and the directions were no help.  It says to put in 15g of coffee for 8oz of water......??? A tablespoon was too strong so again, I'll know for next time! I don't know what instant coffee tastes like so I cannot attest to flavor differences, but I will surely be using this product for any coffee making needs!
# ---------------------------------------------
#
# I am Storm.
# I bought the following products: Electrolux Frigidaire Professional Stainless 7 Quart Slow C, Honeywell Oliver 16" PVC Puncture, Honeywell Oliver 45 Series 8" Leather Composite Toe Waterp, Sabrent 4 Port Mini Portable USB 3.0 Hub  , StarTech StarTech.com USB.
# These products are under the following categories respectively: Slow Cookers, Shoes, Industrial & Construction Boots, Hubs, USB-to-VGA Adapters.
# Here are some features of these products respectively: Large 7-quart Spacewise Design Easy-set cooking options Keep warm function Easy-view tempered glass lid Dishwasher safe ceramic pot, Size:  Size-10, Size:  10 Style:  Brown 6-Inch, Size:  4 Port USB Type A, Color:  White Style:  No Power Delivery.
# For one of the products I bought, I wrote this comment: Pros:Have made several stew/chili type dishes - no problems. Good warm up, constant heat, no hot spots found. The crock itself is thick, well enameled, and substantial. The finish is a little prone to fingerprints, but not as bad as true stainless. Easy to clean up after. Little rubber feet on the bottom keep this cooker from sliding around.Cons:Very basic model at a higher-end price. There's no timer function or target temperature settings, however most slow cookers at this price usually have one or the other.Conclusion:So far, so good, with this Frigidaire.  It's slow cooker #4 in my household (they seem to collect) between a Crockpot and a Hamilton Beach. My previous slow cookers have stood the test of time - all of them 2-6yrs of age, so we'll have to see if this guy will fit in as well.
# ---------------------------------------------
#
# I am Dennis &amp; Veronica.
# I bought the following products: Boogie Board Boogie Board 8.5, STORMTRACKS 11714.06 Youths' Boot , Happy Sales Happy Sales HSST, Ergodyne N, gofanco Pro.
# These products are under the following categories respectively: Graphics Tablets, Boots, Paring Knives, Balaclavas, HDMI-to-VGA Adapters.
# Here are some features of these products respectively: Color:  Black, Size:  Size 08 Color:  Black/Tan, Made in Japan Blade Length: 3.5" Blade 8 7/8". overall Resist Rust Stain Free Dishwasher-safe and Very Easy to Re-Sharpen, Color:  Black, Style:  Micro HDMI to VGA with Audio Support.
# ...
# These products are under the following categories respectively: Industrial & Construction Boots, Industrial & Construction Boots, Cases, Portable Line-In Speakers, French Presses.
# Here are some features of these products respectively: Size:  9 Style:  Black - Steel Toe, Size:  12 Style:  Black - Steel Toe, Color:  Red, Color:  White, Stainless Steel Holds 1000ml or 34oz Dribble-proof spout Dishwasher Safe Double wall feature keeps liquids hot longer.
# For one of the products I bought, I wrote this comment: The JBL Micro II Ultra-Portable Multimedia Speaker (WHITE) is one of the best portable speakers I have ever used. It has a loop for easy retrieval and a fantastic sound as well. The 4-5-hour Lion battery comes in handy as well as the volume adjustment. It also has an extra adapter if you want to connect it to other speakers. It comes with a small bag for travel. For $20.00 this is one of the best portable speakers I've used. I like the white color, usb charger and compact design. Just bought a second one after 3-4 years of heavy use. Great for laptop, ipod, Kindle, smartphone. NOT blue tooth, which is fine by me.  Hope the second one lasts as long as the first. Highly recommend this portable speaker.
# ---------------------------------------------
#
# I am Rachel Dawn.
# I bought the following products: StarTech S, Francois et Mimi Francois et Mimi Soup Mug , Mercer Culinary Mercer Culinary M60200BK7X Millennia Men's Cook , Mercer Culinary Mercer Culinary M61012BK8X Genesis Men's Short S, Olympus Digital Voice Recorder WS.
# These products are under the following categories respectively: Video Converters, Mug Sets, Casual Button-Down Shirts, Chef Jackets, Digital Voice Recorders.
# Here are some features of these products respectively: Size:  USB 2.0 Style:  S-Video/Component, Set of 4 (18 oz.) Color Jumbo Wide Mouth Coffee/Soup Mugs, Size:  Medium Color:  Black, Size:  Medium Color:  Black, Style:  Voice Recorder.
# For one of the products I bought, I wrote this comment: I do not love electronics. They are a necessary evil for me to function in a contemporary world. I am also a songwriter. I get song ideas running through my head at the most insane moments and so often wish I had a recorder with me. I thought it would be pretty cool to have a recorder that I could carry in my purse and use with just a few buttons.
# This one is self-explanatory. I had it up and running in about 3 minutes by turning the power on and following the screen prompts. Perfect.
# Nothing complicated. Easy on. Easy off.
# I recorded a short singing clip and was pretty impressed. The sound was clean and reasonably true for a cheap little hand held device.
# This little fella is going to have a pocket in my purse from now on.
# ---------------------------------------------
#
# I am Nuknuk.
# I bought the following products: Wilton Cake Leveler, Opsales Polarized Black Metal Clip On Flip Up Grey / Gra, Western Digital WD My Passport for Mac 1TB Portable External Har, HomeFlav Flip Top Airtight Coffee Bean Canister , Logitech Turnaround Case with Rotating Frame and.
# These products are under the following categories respectively: Sculpting & Modeling Tools, Sunglasses, External Hard Drives, Storage & Organization, Cases.
# Here are some features of these products respectively: Make your cake top perfectly level for precise decorating- just place adjustable wire in notches to, Size:  52 x 36mm Color:  Gray, Capacity:  2 TB, Airtight lock Dimensions: height 6 " ; diameter 5 " Store up to 1 pound of coffee beans, Style:  iPad Air 2.
# For one of the products I bought, I wrote this comment: It is like a metal clothes' hanger with a steel wire shaped like a bow. My wife and I used this and were just half successful in cutting our cake. We have to be very careful as the crusty outside part of the cake crumbles. I tried slowly; I tried to swing it to and fro like a saw, still came up with a less than perfect cake.Both arms have notches (probably an eight of an inch apart) to adjust for the desired height. Even so, you can use this only on moderate height cakes, not much room for taller cakes. It is not a blade; it is just a piece of steel wire not much different from what you see on a guitar string.A bread knife will do better if only you can do it with a guide to make sure the top is completely parallel to the base.
# ---------------------------------------------
#
# I am Doug Hibbard.
# I bought the following products: ZWILLING J.A. Henckels J.A. Henckels Twin Signature 3, Winco Winware 10, Mercer Culinary Mercer Culinary M60010WHM Millennia Men's Cook J, Sabrent Mini DisplayPort  to HDMI Adapter with S, Monoprice Certified Premium HDMI Cable .
# These products are under the following categories respectively: Paring Knives, Coffee Cups & Mugs, Chef Jackets, DVI-HDMI Adapters, HDMI Cables.
# Here are some features of these products respectively: Made in Germany Stamped Blade Friodur Ice Hardened 3-Rivit Handle with full tang Comfortable ergonomic handle shape, 10-Ounce capacity Made with polycarbonate 3 Snap-on lids included With handle Professional quality, Size:  Large Color:  White, Size:  3840x2160 (4K)@30Hz, Color:  Black Style:  Premium.
# For one of the products I bought, I wrote this comment: Obviously, at this price point you're not expecting the fanciest of dredges. Which is good, because that's what you're getting: not the fanciest of dredges.Does it work? Yes. The lids snap-on tightly. By this, mine does not have the lid come popping off in the middle of shaking. This is good--if the lid didn't hold, it would be a trash product.The lids, though, are a beast to take off and to get snapped on tightly. I'm afraid that with wear and tear, they will loosen. And fail. Again, though, this is entry-level.
# ---------------------------------------------
#
# I am D. H..
# I bought the following products: StarTech StarTech.com 4 Port USB 3.0 Hub , Nesco RG, Sennheiser PMX 686G Sports Earbud Neckband Heads, AmazonBasics Amazonbasics Classic Backpack .
# These products are under the following categories respectively: Hubs, Electric Griddles, Earbud Headphones, Casual Daypacks.
# Here are some features of these products respectively: Color:  Black Style:  4 x USB-A with Built in Cable, Reversible non-stick grill/griddle Embedded heating element Stay-cool handles Power indicator Heavy duty base/drip tray, Style:  Apple, Color:  White Style:  1-Pack.
# For one of the products I bought, I wrote this comment: I got this for my son to use while he is working outside. It is compatible with his iPhone, so I knew it would be good for him, because
# sometimes he sweats and gets wet. It fits him perfectly without slipping off. He has worn these in the rain, and while sweating, and has not
# had any issues with them. The sound quality is very very good, and they really look nice on him.
# He has had many other brands of earphones, and they don't last that long, because he uses them while working, and sooner or later, they
# break. These have stood up so far, and the sound quality is good, so I would highly recommend these just for the durability.
# ---------------------------------------------
#
# I am maximum verbosity.
# I bought the following products: Bialetti Taste of Italy Pizza Chopper , AmazonBasics 14, IKEA Ikea Travel Size Bottles 8 Pack , Francois et Mimi Francois et Mimi Bamboo Multi, JOTO USB Car Charger 3 Ports .
# These products are under the following categories respectively: Pasta & Pizza Tools, Sleeves, Travel Accessories, Breakfast Trays, Chargers & Adapters.
# Here are some features of these products respectively: Pizza chopper 14-inch stainless steel large 14-inch rocking chopper Cuts easily through pizza crust, Size:  11.6 Inch Color:  Purple Style:  1-Pack, Size:  Set of 4, Tray measures 21.5" by 13.75" Adjustable Legs Contains convenient drawer Made of thick and sturdy Bamboo Eco-Friendly, Color:  Silver.
# For one of the products I bought, I wrote this comment: Great little USB Charger that allows you to charge up to three devices at one time, which is great for road trips when the outlets for charging our many mobile devices is very limited. Sometimes we've wanted to be able to plug in our GPS, a cell phone and a tablet while the kids also wanted to plug in their stuff so we're forced to make a choice whether to plug them in to keep the peace in the back seat, but then have no use of our mobile devices, or the ugly alternative?
# Just plug it in to the appropriate outlet plug in your car and you're good to go. Charges quickly and efficiently and is small enough to throw in your bag or glove box.
# Note that the company sent me a sample of this item for my personal use in hopes that I'd write a review, good or bad. This is my honest experience.
# ---------------------------------------------
#
# I am OlyNomad.
# I bought the following products: Magic Chef Magic Chef MCD1311ST 1.3cf 1000W S, Homer Laughlin Fiesta 6, Honeywell Oliver 45 Series 8" Leather Composite Toe Waterp, Wells Lamont Men's Leather Winter Gloves , Monoprice Certified Premium HDMI Cable , Zebra Pen Zebra StylusPen Retractable Ballpoint Pen .
# These products are under the following categories respectively: Countertop Microwave Ovens, Utensil Crocks, Industrial & Construction Boots, Cold Weather Gloves, HDMI Cables, Computers & Accessories.
# Here are some features of these products respectively: Manufacturer: Magic Chef, Made in the USA Vitrified Ceramic body Lead-Free glaze Dishwasher Microwave and Oven safe 5-year chip resistance warranty, Size:  10 Style:  Brown 6-Inch, Size:  Large Color:  Chestnut, Color:  Black Style:  Premium, Style:  Orange Cream Barrel.
# For one of the products I bought, I wrote this comment: We've had ours less than two years and it's already stopped working.  Last night it started smelling like plastic parts were burning when we were cooking in it.  Before that it would turn off randomly.  Power supply was fine, it was the microwave itself.  Called their customer service to find out what options existed and the rep I got (after 20 minutes and a transfer) was extremely rude, answered with a monotone and said there was nothing they could do.  It literally felt like I was interrupting her from painting her nails or something, that same kind of blase tone.  The combination of the short life span of their product and their obvious lack of concern from their customer service guarantees I won't buy another Magic Chef product.
# ---------------------------------------------
#
# I am CRossi.
# I bought the following products: RSVP International Round and Square Decorative Gift Label 48 Piece , SCI Scandicrafts Vegetable Crinkle Cutter and French Fry Slicer, Factory Effex Factory Effex 15, Cosmos Black Neoprene Sleeve Case Bag Cover for , MoKo Samsung Galaxy Note PRO &amp; Tab PRO 12.2 .
# These products are under the following categories respectively: Kitchen Utensils & Gadgets, Mandolines & Slicers, Women, Sleeves, Cases.
# Here are some features of these products respectively: Includes two of each design in round and square Great for any occasion including birthdays anniversaries and holidays Makes eye-catching hang tags, Stainless steel with wooden handle Add crinkle cut design to potatoes and vegetables Hand wash, Size:  Large, Size:  11inch, Color:  Carbon Fiber Black.
# For one of the products I bought, I wrote this comment: Such a great sleeve for my new Macbook Air. It's thin and provides plenty of protection. Love it and I'm very happy with this purchase.
# ...Follow up to this review...I took my Macbook Air to Europe with me and this case was a life saver on more than one occasion. It was stored safely in my backpack as we traveled from The Amalfi Coast>Naples>Rome>Venice>Paris.
# ---------------------------------------------
#
# I am DLH.
# I bought the following products: Slacker  Slacker G2 4 GB 25, Hamilton Beach Hamilton Beach 62676 Performance Plus 6, Comply S, Xtratuf XTRATUF Finatic II Men’s Leather Deck Shoes .
# These products are under the following categories respectively: MP3 & MP4 Players, Hand Mixers, Earpads, Shoes.
# Here are some features of these products respectively: Capacity:  8 GB, Hide-away cord storage Snap-on storage case 290 Watts peak power Special slow first speed Wire beaters whisk & milkshake attachment, Size:  Medium Color:  Charcoal, Size:  10 Color:  Chocolate.
# For one of the products I bought, I wrote this comment: I love toys, and this is one of my new favorites. I love Slacker, and used to listen to it all day long on my laptop while stuck my office. Now with the G2, I have access to millions of songs to take with me everywhere I go. Slacker is free, but you can also get a premium account which allows you even more flexibility to access exactly what songs you want to hear. With a regular account, you get access to any artist you like, but you can't request what songs you want to listen to. A regular account also subjects you to an occasional advertisement every hour, and limits the number of times you can skip a song per hour.
# The G2 is lightweight, has excellent sound, and I get at least 12 hours use between charges. If you're a music lover, then you need to have a Slacker account and a G2.
# ---------------------------------------------
#
# I am Mary Ann.
# I bought the following products: Mastrad Silicone Slim Spatula , Bake Porter Bake Porter Large Baking Sheet , Verbatim Wireless Mini Travel Optical Mouse , Xtratuf XTRATUF Legacy Series 12" Neoprene Men's Fishing, Kinmac Bohemian Pattern Lightweight 13 inch Lapt.
# These products are under the following categories respectively: Spatulas, Kitchen & Dining, Mice, Industrial & Construction, Sleeves.
# Here are some features of these products respectively: Heat resistant to 600 F Non-porous won't stain Hygienic dishwasher safe Won't scratch cookware Good for scaping small cans, Professional quality non-stick bakeware PTFE/PFOA Free Made from carbon steel Hand wash recommended, Color:  Red, Size:  10 Color:  Copper/Tan/Camo, Color:  Rose Capacity:  15 inch-15.6 inch.
# For one of the products I bought, I wrote this comment: This is a very nice spatula.  The handle is long enough to reach into deep bottles and cans.  It is all one piece, so there are no crevices to collect sticky things, and the head cannot clip off.  It is flexible enough to use with my Sunbeam Mixmaster mashing potatoes and mixing baked goods. A great addition to my gadgets.
# ---------------------------------------------
#
# I am G. Hearn.
# I bought the following products: Rubbermaid L3, StarTech StarTech.com 10 ft Certified DisplayPort 1.2 Cab, Honeywell Oliver 16" PVC Puncture, Belkin 6, ZIPIT Grillz Backpack for Kids .
# These products are under the following categories respectively: Ice Cube Molds & Trays, DVI Cables, Shoes, HDMI Cables, Kids' Backpacks.
# Here are some features of these products respectively: Rubbermaid #2879-RD-PERI 2PK Ice Cube Tray^RUBBERMAID INC, Style:  Standard, Size:  Size-10, Size:  6 Feet, Color:  Camo Grey Style:  Extra Side Pocket.
# For one of the products I bought, I wrote this comment: This is certainly not a heavy-duty backpack, but it is a very reasonable duty backpack.  I have the Camo Gray backpack.  The teeth on the zipper pocket on the front are silver.  So when its unzipped, it looks almost like braces.  When its zipped, you cant see the teeth.  The pocket is not too deep, but certainly large enough for pencils, pens, and most phones.  The inside of this backpack is large and roomy.  Unfortunately there are no interior pockets.  There are what I would call water bottle pockets on each side.  The back is slightly padded, as are the shoulder straps.  A little more padding would have been nice.  I keep wondering if the hood, partially covering the back, is for anything.  Ive looked and looked, and I think its only as an accent to the backpack.  Made in China.
# ---------------------------------------------
